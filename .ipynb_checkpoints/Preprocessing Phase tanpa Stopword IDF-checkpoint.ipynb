# %% [markdown]
# import all required library

# %%
import pandas as pd
import re
import string
from tqdm.notebook import tqdm
import nltk
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, ArrayDictionary, StopWordRemover
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, TfidfTransformer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score, recall_score, precision_score
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pickle
from gensim.summarization import summarize, keywords
from collections import Counter
from nltk.tokenize import word_tokenize

# %% [markdown]
# open csv file contains tweets to a dataframe

# %%
data = pd.read_csv("coba_2_label.csv")

data.head()
# Out:
#          id_str                 created_at  \
# 0  1.323188e+18  2020-11-02 08:58:29+00:00
# 1  1.323187e+18  2020-11-02 08:56:15+00:00
# 2  1.323186e+18  2020-11-02 08:52:06+00:00
# 3  1.323185e+18  2020-11-02 08:46:38+00:00
# 4  1.323180e+18  2020-11-02 08:29:45+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twittbot.net/" rel="nofollow">...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/android" ...
#
#                                                 text       label
# 0  i layk dah beyu\n\nyu du?\n\nyesh\n\nyu ar mah...  irrelevant
# 1  Apa apaan nih, tiba tiba @Telkomsel ilang siny...     negatif
# 2  Luhan Byu-Ti-Pul Byu-Ti-Pul Byu-Ti-Pul, Luhan ...  irrelevant
# 3  siang siang dpt kouta gratis dri kak nindy, ma...     positif
# 4  Saya sudah melaksanakan S3 Marketing tapi rewa...     negatif

# %% [markdown]
# double check the data

# %%
del data['id_str']

# %%
data.head()
# Out:
#                   created_at  \
# 0  2020-11-02 08:58:29+00:00
# 1  2020-11-02 08:56:15+00:00
# 2  2020-11-02 08:52:06+00:00
# 3  2020-11-02 08:46:38+00:00
# 4  2020-11-02 08:29:45+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twittbot.net/" rel="nofollow">...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/android" ...
#
#                                                 text       label
# 0  i layk dah beyu\n\nyu du?\n\nyesh\n\nyu ar mah...  irrelevant
# 1  Apa apaan nih, tiba tiba @Telkomsel ilang siny...     negatif
# 2  Luhan Byu-Ti-Pul Byu-Ti-Pul Byu-Ti-Pul, Luhan ...  irrelevant
# 3  siang siang dpt kouta gratis dri kak nindy, ma...     positif
# 4  Saya sudah melaksanakan S3 Marketing tapi rewa...     negatif

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5596 entries, 0 to 5595
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   created_at  5596 non-null   object
#  1   source      5579 non-null   object
#  2   text        5596 non-null   object
#  3   label       5592 non-null   object
# dtypes: object(4)
# memory usage: 175.0+ KB

# %% [markdown]
# double check on column 'label' and fix it if necessary. for example if some variable is still have null value, then fill it with true label wether it positif, negative, or irrelevant

# %%
data[pd.isnull(data["label"])]
# Out:
#                      created_at  \
# 476   2020-10-28 07:09:55+00:00
# 2375  2020-11-09 14:39:38+00:00
# 2516  2020-11-18 00:36:21+00:00
# 3929  2020-11-23 08:55:13+00:00
#
#                                                  source  \
# 476   <a href="https://mobile.twitter.com" rel="nofo...
# 2375  <a href="http://twitter.com/download/android" ...
# 2516  <a href="http://twitter.com/download/iphone" r...
# 3929  <a href="https://ifttt.com" rel="nofollow">IFT...
#
#                                                    text label
# 476   ngeselin bgt baru isi byu yang aman jaya malah...   NaN
# 2375  jaringan kamu kenapa sayang. ko jelek si akhir...   NaN
# 2516  U not even care on artwork and copyright. Bila...   NaN
# 3929  MARIO &amp; LUIGI 🔴🟢 \nvia /r/ MEDI-SHIKI\nby ...   NaN

# %%
data.loc[476]["text"]
# Out:
# 'ngeselin bgt baru isi byu yang aman jaya malah keluar yang staycation 50gb 100rb :D'

# %%
data.loc[2375]["text"]
# Out:
# 'jaringan kamu kenapa sayang. ko jelek si akhir2 ini. ada masalah, hmm? @byu_id'

# %%
data.loc[2516]["text"]
# Out:
# 'U not even care on artwork and copyright. Bila aku kacau kerja kau terus kau tarik GM yer. Did have approved by ceo… https://t.co/JD9K5m7uNl'

# %%
data.loc[3929]["text"]
# Out:
# 'MARIO &amp; LUIGI 🔴🟢 \nvia /r/ MEDI-SHIKI\nby /u/ gaming\n(https://t.co/EgTGma6Eko) #gaming'

# %%
data.loc[476]["label"] = "negatif"
data.loc[2375]["label"] = "negatif"
data.loc[2516]["label"] = "irrelevant"
data.loc[3929]["label"] = "irrelevant"

# %%
data["label"].value_counts()
# Out:
# negatif       2207
# positif       1864
# irrelevant    1525
# Name: label, dtype: int64

# %%
data.loc[476]
# Out:
# created_at                            2020-10-28 07:09:55+00:00
# source        <a href="https://mobile.twitter.com" rel="nofo...
# text          ngeselin bgt baru isi byu yang aman jaya malah...
# label                                                   negatif
# Name: 476, dtype: object

# %%
data[pd.isnull(data["source"])]
# Out:
#                      created_at source  \
# 2475  2020-11-18 05:30:29+00:00    NaN
# 2591  2020-11-17 10:30:11+00:00    NaN
# 2610  2020-11-17 07:00:11+00:00    NaN
# 2740  2020-11-09 19:00:28+00:00    NaN
# 2893  2020-11-16 01:00:18+00:00    NaN
# 2913  2020-11-15 16:30:27+00:00    NaN
# 3178  2020-11-22 21:30:34+00:00    NaN
# 3395  2020-11-22 02:30:27+00:00    NaN
# 3563  2020-11-21 03:30:12+00:00    NaN
# 3568  2020-11-21 03:00:13+00:00    NaN
# 3623  2020-11-20 15:01:14+00:00    NaN
# 4000  2020-11-24 02:30:26+00:00    NaN
# 4016  2020-11-24 00:30:16+00:00    NaN
# 4018  2020-11-24 00:00:12+00:00    NaN
# 4458  2020-11-29 06:00:12+00:00    NaN
# 5329  2020-11-26 19:37:39+00:00    NaN
# 5493  2020-11-30 00:00:49+00:00    NaN
#
#                                                    text       label
# 2475  NK65 Blumen \n by /u/kbartelamia \n \n https:/...  irrelevant
# 2591  Maja X MT3 Susuwatari \n by /u/NAFAL44 \n \n h...  irrelevant
# 2610  KBD8X MKII + MT3 Susuwatari \n by /u/Keebored1...  irrelevant
# 2740  Alais \n by /u/haririjumain \n \n https://t.co...  irrelevant
# 2893  Samurai on Nova \n by /u/Tack_Tau \n \n https:...  irrelevant
# 2913  Finally, DSA Astrolokeys \n by /u/jerolan \n \...  irrelevant
# 3178  GMK Ursa came in \n by /u/Swaedo \n \n https:/...  irrelevant
# 3395  Godslayer Keypora \n by /u/OGBM \n \n https://...  irrelevant
# 3563  KAT Eternal \n by /u/Saavy1 \n \n https://t.co...  irrelevant
# 3568  Maja x Serika \n by /u/oletz \n \n https://t.c...  irrelevant
# 3623  Casio Canoe \n by /u/tsepme7 \n \n https://t.c...  irrelevant
# 4000  Polycarb Canoe Gen2 \n by /u/tsepme7 \n \n htt...  irrelevant
# 4016  Monterey SMK 2gen clicky in box \n by /u/DeDuW...  irrelevant
# 4018  Fujiwara Tofu Keyboard \n by /u/_vastrox_ \n \...  irrelevant
# 4458  KB Nudes \n by /u/tsepme7 \n \n https://t.co/b...  irrelevant
# 5329  Now playing on Pamtengo Radio: Zonga Kanjani b...  irrelevant
# 5493  pamer info time🤝\npemakai byu? iya? bukan?\nka...  irrelevant

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5596 entries, 0 to 5595
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   created_at  5596 non-null   object
#  1   source      5579 non-null   object
#  2   text        5596 non-null   object
#  3   label       5596 non-null   object
# dtypes: object(4)
# memory usage: 175.0+ KB

# %% [markdown]
# delete varable with null value

# %%
data = data.dropna(how='any',axis=0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5579 entries, 0 to 5595
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   created_at  5579 non-null   object
#  1   source      5579 non-null   object
#  2   text        5579 non-null   object
#  3   label       5579 non-null   object
# dtypes: object(4)
# memory usage: 217.9+ KB

# %%
data.describe()
# Out:
#                        created_at  \
# count                        5579
# unique                       5457
# top     2020-11-09 12:46:18+00:00
# freq                            2
#
#                                                    source  \
# count                                                5579
# unique                                                 92
# top     <a href="http://twitter.com/download/android" ...
# freq                                                 3706
#
#                                                      text    label
# count                                                5579     5579
# unique                                               5248        3
# top     Luhan Byu-Ti-Pul Byu-Ti-Pul Byu-Ti-Pul, Luhan ...  negatif
# freq                                                   70     2207

# %% [markdown]
# drop the duplicated data by tweets

# %%
data.drop_duplicates(subset ="text", 
                     keep = "first", inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5248 entries, 0 to 5595
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   created_at  5248 non-null   object
#  1   source      5248 non-null   object
#  2   text        5248 non-null   object
#  3   label       5248 non-null   object
# dtypes: object(4)
# memory usage: 205.0+ KB

# %% [markdown]
# reset the index

# %%
data.reset_index(drop=True, inplace=True)

# %%
data["label"].value_counts()
# Out:
# negatif       2167
# positif       1807
# irrelevant    1274
# Name: label, dtype: int64

# %% [markdown]
# sorting the data by time when the tweets was created

# %%
data.sort_values("created_at", ascending = True)

data
# Out:
#                      created_at  \
# 0     2020-11-02 08:58:29+00:00
# 1     2020-11-02 08:56:15+00:00
# 2     2020-11-02 08:52:06+00:00
# 3     2020-11-02 08:46:38+00:00
# 4     2020-11-02 08:29:45+00:00
# ...                         ...
# 5243  2020-11-30 05:58:22+00:00
# 5244  2020-11-30 05:47:33+00:00
# 5245  2020-11-30 05:47:12+00:00
# 5246  2020-11-30 05:45:40+00:00
# 5247  2020-11-30 05:38:32+00:00
#
#                                                  source  \
# 0     <a href="http://twitter.com/download/iphone" r...
# 1     <a href="http://twitter.com/download/android" ...
# 2     <a href="http://twittbot.net/" rel="nofollow">...
# 3     <a href="http://twitter.com/download/android" ...
# 4     <a href="http://twitter.com/download/android" ...
# ...                                                 ...
# 5243  <a href="https://ifttt.com" rel="nofollow">IFT...
# 5244  <a href="https://www.twitter.com/belift_fess" ...
# 5245  <a href="http://twitter.com/download/android" ...
# 5246  <a href="http://twitter.com/download/android" ...
# 5247  <a href="http://twitter.com/download/android" ...
#
#                                                    text       label
# 0     i layk dah beyu\n\nyu du?\n\nyesh\n\nyu ar mah...  irrelevant
# 1     Apa apaan nih, tiba tiba @Telkomsel ilang siny...     negatif
# 2     Luhan Byu-Ti-Pul Byu-Ti-Pul Byu-Ti-Pul, Luhan ...  irrelevant
# 3     siang siang dpt kouta gratis dri kak nindy, ma...     positif
# 4     Saya sudah melaksanakan S3 Marketing tapi rewa...     negatif
# ...                                                 ...         ...
# 5243  Hot🔥 : happy guru nanak jayanti\n\nposted by u...  irrelevant
# 5244  [by_en-ge-ne]  Bawang sebentar hehe jangan lup...  irrelevant
# 5245  Today’s #byUpedia\n\nKalo kuota yang tertera d...     positif
# 5246  Oy @byu_id kpd byu yg terhormat\nKalo mau ngas...     negatif
# 5247  bagi para pengguna by.u kira kira ini biar bis...     positif
#
# [5248 rows x 4 columns]

# %% [markdown]
# clean up data in column source from html elements

# %%
from bs4 import BeautifulSoup
from pymongo import MongoClient

data['source'] = data['source'].apply(lambda x: BeautifulSoup(x).get_text())

data['source']
# Out:
# 0        Twitter for iPhone
# 1       Twitter for Android
# 2              twittbot.net
# 3       Twitter for Android
# 4       Twitter for Android
#                ...
# 5243                  IFTTT
# 5244           enhypenfess🧡
# 5245    Twitter for Android
# 5246    Twitter for Android
# 5247    Twitter for Android
# Name: source, Length: 5248, dtype: object

# %% [markdown]
# display source list where tweets was created from

# %%
sources = list(set(data['source']))

print(sources)
# Out:
# ['BorderScanner', 'ugm_fess', 'Blog2Social APP', 'tekdotid', 'AWA Music', 'Revive Social App', 'Games Menfess', '1m1c Auto Tweet', 'Twitter Web App', 'SAM Broadcaster Cloud', 'Games Menfess 🎮', 'Plume\xa0for\xa0Android', 'be happy!', 'Echobox', 'ツイタマ for Android', 'Talon Android', 'Dunia aja wal', 'undipmenfess', 'KOMPAS.com  .', 'Nintendo Switch Share', 'UberSocial for iPhone', 'kookvbase', 'Ini sender', 'twitter for iPhone XI pro maxx', 'detikcommunity', 'polbanfess', 'CougarBoard Bot', 'FS Poster', 'Twitter for iPad', 'UZoneID', 'UNNES MENFESS🍌', 'SongsInfo', 'Zapier.com', 'Buffer', 'Shopee_ID', 'Twitter for iPhone', 'AltentX P-Delta-8', 'AutoBase IPB Menfess', 'DrupiFess', 'ContentStudio.io', 'Unsoedfess', 'Support Zona Karya', 'Rpgxg', 'IDCorner.Co.iD', 'subschfess', 'CitCuit', 'Twitter for Mac', 'Hootsuite Inc.', 'worksfess', 'uns menfess', 'TayNew Family!', 'garutfess', 'Twitt-RP', 'IFTTT', 'unairfess', 'Sprout Social', 'indomycafe', '/gabut/', 'Twitter Web Client', 'UB Menfess', 'Spinitron Playlists', 'Unpadfess', 'SUROBOYOFESS', 'Tumblr', 'UberSocial© PRO', 'enhypenfess🧡', 'Bighit United2', 'Jatimfess', 'Harmoni Kediri Lagi', 'UMSfess', 'twittbot.net', 'dlvr.it', 'GENK ANGEL SQUID', 'Instagram', 'by jogmf', 'WordPress.com', 'schfess', 'pdgfess backup account', 'DORbertanya', 'ws ada disini!', 'Twitter for Android', 'TweetDeck', 'TweetCaster for Android', 'Socialbakers', 'LOOKBOOK.nu', 'Pakai masker! Stay safe! -Bot-', 'WP2Zone', 'DOR!', 'pala kao ku betot', 'STAY SAFE! TETAP PAKAI MASKER!', 'FenixApp']

# %% [markdown]
# filter out tweets from an 'unknown source' such as from bot etc, just pick the tweets from legal source

# %%
source = ['Twitter for iPad', 'Twitter for iPhone', 'Twitter for Android', 'Twitter for Mac', 'Twitter Web App']

# %%
data = data[data['source'].isin(source)]

data.head(20)
# Out:
#                    created_at               source  \
# 0   2020-11-02 08:58:29+00:00   Twitter for iPhone
# 1   2020-11-02 08:56:15+00:00  Twitter for Android
# 3   2020-11-02 08:46:38+00:00  Twitter for Android
# 4   2020-11-02 08:29:45+00:00  Twitter for Android
# 5   2020-11-02 07:28:43+00:00  Twitter for Android
# 6   2020-11-02 06:51:44+00:00  Twitter for Android
# 7   2020-11-02 06:41:32+00:00   Twitter for iPhone
# 8   2020-11-02 06:31:45+00:00  Twitter for Android
# 9   2020-11-02 06:03:12+00:00  Twitter for Android
# 10  2020-11-02 05:57:22+00:00  Twitter for Android
# 11  2020-11-02 05:57:00+00:00  Twitter for Android
# 12  2020-11-02 05:54:15+00:00  Twitter for Android
# 13  2020-11-02 05:49:47+00:00  Twitter for Android
# 14  2020-11-02 05:30:21+00:00   Twitter for iPhone
# 15  2020-11-02 05:14:40+00:00  Twitter for Android
# 16  2020-11-02 05:01:18+00:00  Twitter for Android
# 17  2020-11-02 04:56:40+00:00  Twitter for Android
# 18  2020-11-02 04:51:31+00:00  Twitter for Android
# 19  2020-11-02 04:48:32+00:00  Twitter for Android
# 20  2020-11-02 04:31:14+00:00   Twitter for iPhone
#
#                                                  text       label
# 0   i layk dah beyu\n\nyu du?\n\nyesh\n\nyu ar mah...  irrelevant
# 1   Apa apaan nih, tiba tiba @Telkomsel ilang siny...     negatif
# 3   siang siang dpt kouta gratis dri kak nindy, ma...     positif
# 4   Saya sudah melaksanakan S3 Marketing tapi rewa...     negatif
# 5   byu ngajak ribut bgt kalo mati listrik sinyaln...     negatif
# 6   aneh banget kuota byu ku dah habis tp ini masi...     positif
# 7             ini byu dr kemaren lelet bener deh hhhh     negatif
# 8   hello,  @byu_id , mau isi pulsa kenapa belum b...     negatif
# 9               Hallo kak nindy bisa cek dm ? @byu_id     positif
# 10  ini telkom lagi bermasalah apa gimana deh?? wi...     negatif
# 11  ga salah emang milih provider byU hampir setah...     positif
# 12  min @byu_id mau aktivasi login gmail gini mulu...     negatif
# 13  Wow, akhirnya ada provider internet yang bebas...     positif
# 14      Makasih nindy @byu_id https://t.co/ZGfH6k5vZJ     positif
# 15  Min kok kuota spotify sama youtube gak bisa di...     negatif
# 16                  Coba tebak mana yang bener, gaes?  irrelevant
# 17  TLSEL APA APAAN SIH INI BYU SAMA SIMPATI GAK B...     negatif
# 18                          Mba @Afisk_ yu sri di jak  irrelevant
# 19                            Byu jelek bgt tumben 😩😭     negatif
# 20  Selamat 6 monthiversary, makasih ya kuota grat...     positif

# %%
#data.to_csv("coba_fix_source.csv", index=False)

# %% [markdown]
# delete all irrelevant tweets

# %%
data = data[~data.label.str.contains("irrelevant")]

data.reset_index(drop=True, inplace=True)

data.head(20)
# Out:
#                    created_at               source  \
# 0   2020-11-02 08:56:15+00:00  Twitter for Android
# 1   2020-11-02 08:46:38+00:00  Twitter for Android
# 2   2020-11-02 08:29:45+00:00  Twitter for Android
# 3   2020-11-02 07:28:43+00:00  Twitter for Android
# 4   2020-11-02 06:51:44+00:00  Twitter for Android
# 5   2020-11-02 06:41:32+00:00   Twitter for iPhone
# 6   2020-11-02 06:31:45+00:00  Twitter for Android
# 7   2020-11-02 06:03:12+00:00  Twitter for Android
# 8   2020-11-02 05:57:22+00:00  Twitter for Android
# 9   2020-11-02 05:57:00+00:00  Twitter for Android
# 10  2020-11-02 05:54:15+00:00  Twitter for Android
# 11  2020-11-02 05:49:47+00:00  Twitter for Android
# 12  2020-11-02 05:30:21+00:00   Twitter for iPhone
# 13  2020-11-02 05:14:40+00:00  Twitter for Android
# 14  2020-11-02 04:56:40+00:00  Twitter for Android
# 15  2020-11-02 04:48:32+00:00  Twitter for Android
# 16  2020-11-02 04:31:14+00:00   Twitter for iPhone
# 17  2020-11-02 04:17:19+00:00  Twitter for Android
# 18  2020-11-02 04:08:52+00:00      Twitter Web App
# 19  2020-11-02 03:37:43+00:00  Twitter for Android
#
#                                                  text    label
# 0   Apa apaan nih, tiba tiba @Telkomsel ilang siny...  negatif
# 1   siang siang dpt kouta gratis dri kak nindy, ma...  positif
# 2   Saya sudah melaksanakan S3 Marketing tapi rewa...  negatif
# 3   byu ngajak ribut bgt kalo mati listrik sinyaln...  negatif
# 4   aneh banget kuota byu ku dah habis tp ini masi...  positif
# 5             ini byu dr kemaren lelet bener deh hhhh  negatif
# 6   hello,  @byu_id , mau isi pulsa kenapa belum b...  negatif
# 7               Hallo kak nindy bisa cek dm ? @byu_id  positif
# 8   ini telkom lagi bermasalah apa gimana deh?? wi...  negatif
# 9   ga salah emang milih provider byU hampir setah...  positif
# 10  min @byu_id mau aktivasi login gmail gini mulu...  negatif
# 11  Wow, akhirnya ada provider internet yang bebas...  positif
# 12      Makasih nindy @byu_id https://t.co/ZGfH6k5vZJ  positif
# 13  Min kok kuota spotify sama youtube gak bisa di...  negatif
# 14  TLSEL APA APAAN SIH INI BYU SAMA SIMPATI GAK B...  negatif
# 15                            Byu jelek bgt tumben 😩😭  negatif
# 16  Selamat 6 monthiversary, makasih ya kuota grat...  positif
# 17         byu dipake gim rasanya ping ingin menangos  negatif
# 18  ini ByU tumben banget burik kek indihome sinya...  negatif
# 19  Halo @byu_id mau tanya, saya ada pesan sim car...  negatif

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3804 entries, 0 to 3803
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   created_at  3804 non-null   object
#  1   source      3804 non-null   object
#  2   text        3804 non-null   object
#  3   label       3804 non-null   object
# dtypes: object(4)
# memory usage: 119.0+ KB

# %% [markdown]
# clean up tweets from all junk string like url, symbol, etc.

# %%
output_text = []
def clean_text(list_of_text):
  for text in tqdm(list_of_text):    
    text = text.translate(str.maketrans("","", string.punctuation)).lower()
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r'@\w+ ', '', text)
    text = re.sub(r'#\w+ ', '', text)
    text = re.sub(r"pic\S+", "", text)
    text = re.sub(r"www\S+", "", text)
    text = re.sub(r'\n+', ' ', text)
    text = re.sub(r'[^a-zA-Z0-9]', ' ', text)
    output_text.append(text)
  return output_text

# %%
data['text'] = clean_text(list(data['text']))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3804.0), HTML(value='')))

# %%
data.head(20)
# Out:
#                    created_at               source  \
# 0   2020-11-02 08:56:15+00:00  Twitter for Android
# 1   2020-11-02 08:46:38+00:00  Twitter for Android
# 2   2020-11-02 08:29:45+00:00  Twitter for Android
# 3   2020-11-02 07:28:43+00:00  Twitter for Android
# 4   2020-11-02 06:51:44+00:00  Twitter for Android
# 5   2020-11-02 06:41:32+00:00   Twitter for iPhone
# 6   2020-11-02 06:31:45+00:00  Twitter for Android
# 7   2020-11-02 06:03:12+00:00  Twitter for Android
# 8   2020-11-02 05:57:22+00:00  Twitter for Android
# 9   2020-11-02 05:57:00+00:00  Twitter for Android
# 10  2020-11-02 05:54:15+00:00  Twitter for Android
# 11  2020-11-02 05:49:47+00:00  Twitter for Android
# 12  2020-11-02 05:30:21+00:00   Twitter for iPhone
# 13  2020-11-02 05:14:40+00:00  Twitter for Android
# 14  2020-11-02 04:56:40+00:00  Twitter for Android
# 15  2020-11-02 04:48:32+00:00  Twitter for Android
# 16  2020-11-02 04:31:14+00:00   Twitter for iPhone
# 17  2020-11-02 04:17:19+00:00  Twitter for Android
# 18  2020-11-02 04:08:52+00:00      Twitter Web App
# 19  2020-11-02 03:37:43+00:00  Twitter for Android
#
#                                                  text    label
# 0   apa apaan nih tiba tiba telkomsel ilang sinyal...  negatif
# 1   siang siang dpt kouta gratis dri kak nindy mak...  positif
# 2   saya sudah melaksanakan s3 marketing tapi rewa...  negatif
# 3   byu ngajak ribut bgt kalo mati listrik sinyaln...  negatif
# 4   aneh banget kuota byu ku dah habis tp ini masi...  positif
# 5             ini byu dr kemaren lelet bener deh hhhh  negatif
# 6   hello  byuid  mau isi pulsa kenapa belum bisa ...  negatif
# 7                  hallo kak nindy bisa cek dm  byuid  positif
# 8   ini telkom lagi bermasalah apa gimana deh wifi...  negatif
# 9   ga salah emang milih provider byu hampir setah...  positif
# 10  min byuid mau aktivasi login gmail gini mulu  ...  negatif
# 11  wow akhirnya ada provider internet yang bebasi...  positif
# 12                               makasih nindy byuid   positif
# 13  min kok kuota spotify sama youtube gak bisa di...  negatif
# 14  tlsel apa apaan sih ini byu sama simpati gak b...  negatif
# 15                            byu jelek bgt tumben     negatif
# 16  selamat 6 monthiversary makasih ya kuota grati...  positif
# 17         byu dipake gim rasanya ping ingin menangos  negatif
# 18  ini byu tumben banget burik kek indihome sinya...  negatif
# 19  halo byuid mau tanya saya ada pesan sim card b...  negatif

# %% [markdown]
# replace slang word list with the formal one that can be found on KBBI

# %%
slanglist = pd.read_csv("slanglist.csv" ,encoding = "ISO-8859-1")

# %%
slanglist
# Out:
#          slang    formal
# 0         woww       wow
# 1        aminn      amin
# 2          met   selamat
# 3       netaas   menetas
# 4      keberpa  keberapa
# ...        ...       ...
# 17983    ambek      sama
# 17984     isok      bisa
# 17985   sakiki  sekarang
# 17986      wes     sudah
# 17987      neh      lagi
#
# [17988 rows x 2 columns]

# %%
def slang(text):
    text = str(text).lower()
    text = nltk.word_tokenize(text)
    ul = 0
    for a in slanglist['slang']:
        w = 0
        for kt in text:
            if kt ==a:
                text[w] = slanglist['formal'][ul]
            w = w+1
        ul=ul+1
    kal = ""
    for kl in text:
        kal = kal + " " + kl
    text = kal
    return kal

# %%
data['text'] = data['text'].apply(lambda text : slang(text))

# %%
data.head(20)
# Out:
#                    created_at               source  \
# 0   2020-11-02 08:56:15+00:00  Twitter for Android
# 1   2020-11-02 08:46:38+00:00  Twitter for Android
# 2   2020-11-02 08:29:45+00:00  Twitter for Android
# 3   2020-11-02 07:28:43+00:00  Twitter for Android
# 4   2020-11-02 06:51:44+00:00  Twitter for Android
# 5   2020-11-02 06:41:32+00:00   Twitter for iPhone
# 6   2020-11-02 06:31:45+00:00  Twitter for Android
# 7   2020-11-02 06:03:12+00:00  Twitter for Android
# 8   2020-11-02 05:57:22+00:00  Twitter for Android
# 9   2020-11-02 05:57:00+00:00  Twitter for Android
# 10  2020-11-02 05:54:15+00:00  Twitter for Android
# 11  2020-11-02 05:49:47+00:00  Twitter for Android
# 12  2020-11-02 05:30:21+00:00   Twitter for iPhone
# 13  2020-11-02 05:14:40+00:00  Twitter for Android
# 14  2020-11-02 04:56:40+00:00  Twitter for Android
# 15  2020-11-02 04:48:32+00:00  Twitter for Android
# 16  2020-11-02 04:31:14+00:00   Twitter for iPhone
# 17  2020-11-02 04:17:19+00:00  Twitter for Android
# 18  2020-11-02 04:08:52+00:00      Twitter Web App
# 19  2020-11-02 03:37:43+00:00  Twitter for Android
#
#                                                  text    label
# 0    apa apaan nih tiba tiba telkomsel hilang siny...  negatif
# 1    siang siang dapat kuota gratis dari kak nindy...  positif
# 2    saya sudah melaksanakan s3 marketing tapi bon...  negatif
# 3    byu mengajak ribut banget kalau mati listrik ...  negatif
# 4    aneh banget kuota byu ku deh habis tapi ini m...  positif
# 5           ini byu dari kemarin lelet benar deh hhhh  negatif
# 6    halo byu mau isi pulsa kenapa belum bisa juga ya  negatif
# 7                      halo kak nindy bisa cek dm byu  positif
# 8    ini telkomsel lagi bermasalah apa bagaimana d...  negatif
# 9    enggak salah memang memilih provider byu hamp...  positif
# 10   admin byu mau aktivasi login gmail begini mel...  negatif
# 11   wow akhirnya ada provider internet yang bebas...  positif
# 12                              terimakasih nindy byu  positif
# 13   admin kok kuota spotify sama youtube enggak b...  negatif
# 14   telkomsel apa apaan sih ini byu sama simpati ...  negatif
# 15                            byu jelek banget tumben  negatif
# 16   selamat 6 monthiversary terimakasih ya kuota ...  positif
# 17        byu dipakai gim rasanya ping ingin menangis  negatif
# 18   ini byu tumben banget buruk kayak indihome si...  negatif
# 19   halo byu mau tanya saya ada pesan sim kartu b...  negatif

# %% [markdown]
# filtering important word with stopword remover

# %%
data.head(20)
# Out:
#                    created_at               source  \
# 0   2020-11-02 08:56:15+00:00  Twitter for Android
# 1   2020-11-02 08:46:38+00:00  Twitter for Android
# 2   2020-11-02 08:29:45+00:00  Twitter for Android
# 3   2020-11-02 07:28:43+00:00  Twitter for Android
# 4   2020-11-02 06:51:44+00:00  Twitter for Android
# 5   2020-11-02 06:41:32+00:00   Twitter for iPhone
# 6   2020-11-02 06:31:45+00:00  Twitter for Android
# 7   2020-11-02 06:03:12+00:00  Twitter for Android
# 8   2020-11-02 05:57:22+00:00  Twitter for Android
# 9   2020-11-02 05:57:00+00:00  Twitter for Android
# 10  2020-11-02 05:54:15+00:00  Twitter for Android
# 11  2020-11-02 05:49:47+00:00  Twitter for Android
# 12  2020-11-02 05:30:21+00:00   Twitter for iPhone
# 13  2020-11-02 05:14:40+00:00  Twitter for Android
# 14  2020-11-02 04:56:40+00:00  Twitter for Android
# 15  2020-11-02 04:48:32+00:00  Twitter for Android
# 16  2020-11-02 04:31:14+00:00   Twitter for iPhone
# 17  2020-11-02 04:17:19+00:00  Twitter for Android
# 18  2020-11-02 04:08:52+00:00      Twitter Web App
# 19  2020-11-02 03:37:43+00:00  Twitter for Android
#
#                                                  text    label
# 0    apa apaan nih tiba tiba telkomsel hilang siny...  negatif
# 1    siang siang dapat kuota gratis dari kak nindy...  positif
# 2    saya sudah melaksanakan s3 marketing tapi bon...  negatif
# 3    byu mengajak ribut banget kalau mati listrik ...  negatif
# 4    aneh banget kuota byu ku deh habis tapi ini m...  positif
# 5           ini byu dari kemarin lelet benar deh hhhh  negatif
# 6    halo byu mau isi pulsa kenapa belum bisa juga ya  negatif
# 7                      halo kak nindy bisa cek dm byu  positif
# 8    ini telkomsel lagi bermasalah apa bagaimana d...  negatif
# 9    enggak salah memang memilih provider byu hamp...  positif
# 10   admin byu mau aktivasi login gmail begini mel...  negatif
# 11   wow akhirnya ada provider internet yang bebas...  positif
# 12                              terimakasih nindy byu  positif
# 13   admin kok kuota spotify sama youtube enggak b...  negatif
# 14   telkomsel apa apaan sih ini byu sama simpati ...  negatif
# 15                            byu jelek banget tumben  negatif
# 16   selamat 6 monthiversary terimakasih ya kuota ...  positif
# 17        byu dipakai gim rasanya ping ingin menangis  negatif
# 18   ini byu tumben banget buruk kayak indihome si...  negatif
# 19   halo byu mau tanya saya ada pesan sim kartu b...  negatif

# %%
# create stemmer
stem_factory = StemmerFactory()
stemmer = stem_factory.create_stemmer()
output_text = []
def stem_data(list_of_text):
  for text in tqdm(list_of_text): 
    text = stemmer.stem(text)
    output_text.append(text)
  return output_text

# %%
data['text'] = stem_data(list(data['text']))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3804.0), HTML(value='')))

# %%
data.head(20)
# Out:
#                    created_at               source  \
# 0   2020-11-02 08:56:15+00:00  Twitter for Android
# 1   2020-11-02 08:46:38+00:00  Twitter for Android
# 2   2020-11-02 08:29:45+00:00  Twitter for Android
# 3   2020-11-02 07:28:43+00:00  Twitter for Android
# 4   2020-11-02 06:51:44+00:00  Twitter for Android
# 5   2020-11-02 06:41:32+00:00   Twitter for iPhone
# 6   2020-11-02 06:31:45+00:00  Twitter for Android
# 7   2020-11-02 06:03:12+00:00  Twitter for Android
# 8   2020-11-02 05:57:22+00:00  Twitter for Android
# 9   2020-11-02 05:57:00+00:00  Twitter for Android
# 10  2020-11-02 05:54:15+00:00  Twitter for Android
# 11  2020-11-02 05:49:47+00:00  Twitter for Android
# 12  2020-11-02 05:30:21+00:00   Twitter for iPhone
# 13  2020-11-02 05:14:40+00:00  Twitter for Android
# 14  2020-11-02 04:56:40+00:00  Twitter for Android
# 15  2020-11-02 04:48:32+00:00  Twitter for Android
# 16  2020-11-02 04:31:14+00:00   Twitter for iPhone
# 17  2020-11-02 04:17:19+00:00  Twitter for Android
# 18  2020-11-02 04:08:52+00:00      Twitter Web App
# 19  2020-11-02 03:37:43+00:00  Twitter for Android
#
#                                                  text    label
# 0   apa apa nih tiba tiba telkomsel hilang sinyal ...  negatif
# 1   siang siang dapat kuota gratis dari kak nindy ...  positif
# 2   saya sudah laksana s3 marketing tapi bonus eng...  negatif
# 3   byu ajak ribut banget kalau mati listrik sinya...  negatif
# 4   aneh banget kuota byu ku deh habis tapi ini ma...  positif
# 5           ini byu dari kemarin lelet benar deh hhhh  negatif
# 6    halo byu mau isi pulsa kenapa belum bisa juga ya  negatif
# 7                      halo kak nindy bisa cek dm byu  positif
# 8   ini telkomsel lagi masalah apa bagaimana deh w...  negatif
# 9   enggak salah memang pilih provider byu hampir ...  positif
# 10  admin byu mau aktivasi login gmail begini melu...  negatif
# 11  wow akhir ada provider internet yang bebas kam...  positif
# 12                              terimakasih nindy byu  positif
# 13  admin kok kuota spotify sama youtube enggak bi...  negatif
# 14  telkomsel apa apa sih ini byu sama simpati eng...  negatif
# 15                            byu jelek banget tumben  negatif
# 16  selamat 6 monthiversary terimakasih ya kuota g...  positif
# 17               byu pakai gim rasa ping ingin menang  negatif
# 18  ini byu tumben banget buruk kayak indihome sinyal  negatif
# 19  halo byu mau tanya saya ada pesan sim kartu ba...  negatif

# %% [markdown]
# split the data to make training data and testing data

# %%
tweet = data.text
label = data.label

# %%
tweet_train1, tweet_test1, label_train1, label_test1 = train_test_split(tweet,label,test_size=0.1, random_state=0)
tweet_train2, tweet_test2, label_train2, label_test2 = train_test_split(tweet,label,test_size=0.15, random_state=0)
tweet_train3, tweet_test3, label_train3, label_test3 = train_test_split(tweet,label,test_size=0.20, random_state=0)
tweet_train4, tweet_test4, label_train4, label_test4 = train_test_split(tweet,label,test_size=0.25, random_state=0)
tweet_train5, tweet_test5, label_train5, label_test5 = train_test_split(tweet,label,test_size=0.3, random_state=0)

# %% [markdown]
# make the sentiment analysis model with Naive Bayes Classifier and TF-IDF feature extraction

# %%
tfvec1 = TfidfVectorizer(min_df=5, max_df=0.95, sublinear_tf = True,use_idf = True,ngram_range=(1, 2))
tfvec2 = TfidfVectorizer(min_df=5, max_df=0.95, sublinear_tf = True,use_idf = True,ngram_range=(1, 2))
tfvec3 = TfidfVectorizer(min_df=5, max_df=0.95, sublinear_tf = True,use_idf = True,ngram_range=(1, 2))
tfvec4 = TfidfVectorizer(min_df=5, max_df=0.95, sublinear_tf = True,use_idf = True,ngram_range=(1, 2))
tfvec5 = TfidfVectorizer(min_df=5, max_df=0.95, sublinear_tf = True,use_idf = True,ngram_range=(1, 2))

# %%
#tweet_train_vec = tfvec.fit_transform(tweet_train)

# %%
clf_mnb1 = MultinomialNB(alpha=1.0)
clf_mnb2 = MultinomialNB(alpha=1.0)
clf_mnb3 = MultinomialNB(alpha=1.0)
clf_mnb4 = MultinomialNB(alpha=1.0)
clf_mnb5 = MultinomialNB(alpha=1.0)

# %%
#membuat pipeline MNB()
model_mnb1 = Pipeline([
    ('tfidf', tfvec1),
    ('classifier', clf_mnb1)
])

#membuat pipeline MNB()
model_mnb2 = Pipeline([
    ('tfidf', tfvec2),
    ('classifier', clf_mnb2)
])

#membuat pipeline MNB()
model_mnb3 = Pipeline([
    ('tfidf', tfvec3),
    ('classifier', clf_mnb3)
])

#membuat pipeline MNB()
model_mnb4 = Pipeline([
    ('tfidf', tfvec4),
    ('classifier', clf_mnb4)
])

#membuat pipeline MNB()
model_mnb5 = Pipeline([
    ('tfidf', tfvec5),
    ('classifier', clf_mnb5)
])

# %%
#Train data X dan y menggunakan BernoulliNB()
model_mnb1.fit(tweet_train1, label_train1)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.95, min_df=5, ngram_range=(1, 2),
#                                  sublinear_tf=True)),
#                 ('classifier', MultinomialNB())])

# %%
#Train data X dan y menggunakan BernoulliNB()
model_mnb2.fit(tweet_train2, label_train2)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.95, min_df=5, ngram_range=(1, 2),
#                                  sublinear_tf=True)),
#                 ('classifier', MultinomialNB())])

# %%
#Train data X dan y menggunakan BernoulliNB()
model_mnb3.fit(tweet_train3, label_train3)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.95, min_df=5, ngram_range=(1, 2),
#                                  sublinear_tf=True)),
#                 ('classifier', MultinomialNB())])

# %%
#Train data X dan y menggunakan BernoulliNB()
model_mnb4.fit(tweet_train4, label_train4)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.95, min_df=5, ngram_range=(1, 2),
#                                  sublinear_tf=True)),
#                 ('classifier', MultinomialNB())])

# %%
#Train data X dan y menggunakan BernoulliNB()
model_mnb5.fit(tweet_train5, label_train5)
# Out:
# Pipeline(steps=[('tfidf',
#                  TfidfVectorizer(max_df=0.95, min_df=5, ngram_range=(1, 2),
#                                  sublinear_tf=True)),
#                 ('classifier', MultinomialNB())])

# %%
hasil_mnb_S1 = model_mnb1.predict(tweet_test1)
hasil_mnb_S2 = model_mnb2.predict(tweet_test2)
hasil_mnb_S3 = model_mnb3.predict(tweet_test3)
hasil_mnb_S4 = model_mnb4.predict(tweet_test4)
hasil_mnb_S5 = model_mnb5.predict(tweet_test5)

# %% [markdown]
# show the confusion matrix to evaluate the model

# %%
cm_S1 = confusion_matrix(hasil_mnb_S1, label_test1)
cm_S2 = confusion_matrix(hasil_mnb_S2, label_test2)
cm_S3 = confusion_matrix(hasil_mnb_S3, label_test3)
cm_S4 = confusion_matrix(hasil_mnb_S4, label_test4)
cm_S5 = confusion_matrix(hasil_mnb_S5, label_test5)

print(cm_S1)
print(cm_S2)
print(cm_S3)
print(cm_S4)
print(cm_S5)
# Out:
# [[181  30]
#  [ 20 150]]
# [[264  55]
#  [ 34 218]]
# [[349  70]
#  [ 48 294]]
# [[453  81]
#  [ 60 357]]
# [[541 103]
#  [ 75 423]]

# %%
TN1, FN1, FP1, TP1 = cm_S1[0][0], cm_S1[0][1], cm_S1[1][0], cm_S1[1][1]

# %%
TN2, FN2, FP2, TP2 = cm_S2[0][0], cm_S2[0][1], cm_S2[1][0], cm_S2[1][1]

# %%
TN3, FN3, FP3, TP3 = cm_S3[0][0], cm_S3[0][1], cm_S3[1][0], cm_S3[1][1]

# %%
TN4, FN4, FP4, TP4 = cm_S4[0][0], cm_S4[0][1], cm_S4[1][0], cm_S4[1][1]

# %%
TN5, FN5, FP5, TP5 = cm_S5[0][0], cm_S5[0][1], cm_S5[1][0], cm_S5[1][1]

# %%
f, ax = plt.subplots(figsize=(8, 5))
sns.heatmap(confusion_matrix(label_test1, hasil_mnb_S1), annot=True, fmt=".0f", ax=ax)
plt.title("Confusion Matrix 90:10")
plt.xlabel("Prediksi Label")
plt.ylabel("Label Benar")
plt.show()

# %%
#Convert hasil ke list (hasil tadinya dalam bentuk ndarray)

l_hasil_S1 = list(hasil_mnb_S1)

print("Skenario tanpa stopword 90:10")
print("==============================")
print('\n')
print('Jumlah Data tweet_train : ',len(tweet_train1))
print('Jumlah Data label_train : ',len(label_train1))
print('Jumlah Data tweet_test : ',len(tweet_test1))
print('Jumlah Data label_test : ',len(label_test1))
print('\n')
print("Prediksi tweet positif: " + str(l_hasil_S1.count("positif")))
print("Prediksi tweet negatif: " + str(l_hasil_S1.count("negatif")))
#print("Prediksi tweet irelevant: " + str(l_hasil.count("irrelevant")))
#print("Prediksi tweet netral: " + str(l_hasil.count("netral")))

num_positif1 = 100*(l_hasil_S1.count("positif")/tweet_test1.count())
num_negatif1 = 100*(l_hasil_S1.count("negatif")/tweet_test1.count())

print("Persentase tweet positif = {:.2f} %".format(num_positif1))
print("Persentase tweet negatif = {:.2f} %".format(num_negatif1))

print('\n')
acc1 = 100*accuracy_score(hasil_mnb_S1,label_test1)
recall1 = 100*(TP1/(TP1+FN1))
specifity1 = 100*(TN1/(TN1+FP1))
precision1 = 100*(TP1/(TP1+FP1))
f1_score1 = 100*((2*TP1)/((2*TP1)+FP1+FN1))

print("Ketelitian = {:.2f} %".format(acc1))
print("recall = {:.2f} %".format(recall1))
print("precision = {:.2f} %".format(precision1))
print("f1_score = {:.2f} %".format(f1_score1))

print('\n')
print(classification_report(hasil_mnb_S1, label_test1))
# Out:
# Skenario tanpa stopword 90:10
# ==============================
#
#
# Jumlah Data tweet_train :  3423
# Jumlah Data label_train :  3423
# Jumlah Data tweet_test :  381
# Jumlah Data label_test :  381
#
#
# Prediksi tweet positif: 170
# Prediksi tweet negatif: 211
# Persentase tweet positif = 44.62 %
# Persentase tweet negatif = 55.38 %
#
#
# Ketelitian = 86.88 %
# recall = 83.33 %
# precision = 88.24 %
# f1_score = 85.71 %
#
#
#               precision    recall  f1-score   support
#
#      negatif       0.90      0.86      0.88       211
#      positif       0.83      0.88      0.86       170
#
#     accuracy                           0.87       381
#    macro avg       0.87      0.87      0.87       381
# weighted avg       0.87      0.87      0.87       381

# %%
f, ax = plt.subplots(figsize=(8, 5))
sns.heatmap(confusion_matrix(label_test2, hasil_mnb_S2), annot=True, fmt=".0f", ax=ax)
plt.title("Confusion Matrix 85:15")
plt.xlabel("Prediksi Label")
plt.ylabel("Label Benar")
plt.show()

# %%
#Convert hasil ke list (hasil tadinya dalam bentuk ndarray)

l_hasil_S2 = list(hasil_mnb_S2)

print("Skenario tanpa stopword 85:15")
print("==============================")
print('\n')
print('Jumlah Data tweet_train : ',len(tweet_train2))
print('Jumlah Data label_train : ',len(label_train2))
print('Jumlah Data tweet_test : ',len(tweet_test2))
print('Jumlah Data label_test : ',len(label_test2))

print('\n')
print("Prediksi tweet positif: " + str(l_hasil_S2.count("positif")))
print("Prediksi tweet negatif: " + str(l_hasil_S2.count("negatif")))
#print("Prediksi tweet irelevant: " + str(l_hasil.count("irrelevant")))
#print("Prediksi tweet netral: " + str(l_hasil.count("netral")))

num_positif2 = 100*(l_hasil_S2.count("positif")/tweet_test2.count())
num_negatif2 = 100*(l_hasil_S2.count("negatif")/tweet_test2.count())

print("Persentase tweet positif = {:.2f} %".format(num_positif2))
print("Persentase tweet negatif = {:.2f} %".format(num_negatif2))

print('\n')
acc2 = 100*accuracy_score(hasil_mnb_S2,label_test2)
recall2 = 100*(TP2/(TP2+FN2))
specifity2 = 100*(TN2/(TN2+FP2))
precision2 = 100*(TP2/(TP2+FP2))
f1_score2 = 100*((2*TP2)/((2*TP2)+FP2+FN2))

print("Ketelitian = {:.2f} %".format(acc2))
print("recall = {:.2f} %".format(recall2))
print("precision = {:.2f} %".format(precision2))
print("f1_score = {:.2f} %".format(f1_score2))

print('\n')
print(classification_report(hasil_mnb_S2, label_test2))
# Out:
# Skenario tanpa stopword 85:15
# ==============================
#
#
# Jumlah Data tweet_train :  3233
# Jumlah Data label_train :  3233
# Jumlah Data tweet_test :  571
# Jumlah Data label_test :  571
#
#
# Prediksi tweet positif: 252
# Prediksi tweet negatif: 319
# Persentase tweet positif = 44.13 %
# Persentase tweet negatif = 55.87 %
#
#
# Ketelitian = 84.41 %
# recall = 79.85 %
# precision = 86.51 %
# f1_score = 83.05 %
#
#
#               precision    recall  f1-score   support
#
#      negatif       0.89      0.83      0.86       319
#      positif       0.80      0.87      0.83       252
#
#     accuracy                           0.84       571
#    macro avg       0.84      0.85      0.84       571
# weighted avg       0.85      0.84      0.84       571

# %%
f, ax = plt.subplots(figsize=(8, 5))
sns.heatmap(confusion_matrix(label_test3, hasil_mnb_S3), annot=True, fmt=".0f", ax=ax)
plt.title("Confusion Matrix 80:20")
plt.xlabel("Prediksi Label")
plt.ylabel("Label Benar")
plt.show()

# %%
#Convert hasil ke list (hasil tadinya dalam bentuk ndarray)

l_hasil_S3 = list(hasil_mnb_S3)

print("Skenario tanpa stopword 80:20")
print("==============================")
print('\n')
print('Jumlah Data tweet_train : ',len(tweet_train3))
print('Jumlah Data label_train : ',len(label_train3))
print('Jumlah Data tweet_test : ',len(tweet_test3))
print('Jumlah Data label_test : ',len(label_test3))

print('\n')
print("Prediksi tweet positif: " + str(l_hasil_S3.count("positif")))
print("Prediksi tweet negatif: " + str(l_hasil_S3.count("negatif")))
#print("Prediksi tweet irelevant: " + str(l_hasil.count("irrelevant")))
#print("Prediksi tweet netral: " + str(l_hasil.count("netral")))

num_positif3 = 100*(l_hasil_S3.count("positif")/tweet_test3.count())
num_negatif3 = 100*(l_hasil_S3.count("negatif")/tweet_test3.count())

print("Persentase tweet positif = {:.2f} %".format(num_positif3))
print("Persentase tweet negatif = {:.2f} %".format(num_negatif3))

print('\n')
acc3 = 100*accuracy_score(hasil_mnb_S3,label_test3)
recall3 = 100*(TP3/(TP3+FN3))
specifity3 = 100*(TN3/(TN3+FP3))
precision3 = 100*(TP3/(TP3+FP3))
f1_score3 = 100*((2*TP3)/((2*TP3)+FP3+FN3))

print("Ketelitian = {:.2f} %".format(acc3))
print("recall = {:.2f} %".format(recall3))
print("precision = {:.2f} %".format(precision3))
print("f1_score = {:.2f} %".format(f1_score3))

print('\n')
print(classification_report(hasil_mnb_S3, label_test3))
# Out:
# Skenario tanpa stopword 80:20
# ==============================
#
#
# Jumlah Data tweet_train :  3043
# Jumlah Data label_train :  3043
# Jumlah Data tweet_test :  761
# Jumlah Data label_test :  761
#
#
# Prediksi tweet positif: 342
# Prediksi tweet negatif: 419
# Persentase tweet positif = 44.94 %
# Persentase tweet negatif = 55.06 %
#
#
# Ketelitian = 84.49 %
# recall = 80.77 %
# precision = 85.96 %
# f1_score = 83.29 %
#
#
#               precision    recall  f1-score   support
#
#      negatif       0.88      0.83      0.86       419
#      positif       0.81      0.86      0.83       342
#
#     accuracy                           0.84       761
#    macro avg       0.84      0.85      0.84       761
# weighted avg       0.85      0.84      0.85       761

# %%
f, ax = plt.subplots(figsize=(8, 5))
sns.heatmap(confusion_matrix(label_test4, hasil_mnb_S4), annot=True, fmt=".0f", ax=ax)
plt.title("Confusion Matrix 75:25")
plt.xlabel("Prediksi Label")
plt.ylabel("Label Benar")
plt.show()

# %%
#Convert hasil ke list (hasil tadinya dalam bentuk ndarray)

l_hasil_S4 = list(hasil_mnb_S4)

print("Skenario tanpa stopword 75:25")
print("==============================")
print('\n')
print('Jumlah Data tweet_train : ',len(tweet_train4))
print('Jumlah Data label_train : ',len(label_train4))
print('Jumlah Data tweet_test : ',len(tweet_test4))
print('Jumlah Data label_test : ',len(label_test4))

print('\n')
print("Prediksi tweet positif: " + str(l_hasil_S4.count("positif")))
print("Prediksi tweet negatif: " + str(l_hasil_S4.count("negatif")))
#print("Prediksi tweet irelevant: " + str(l_hasil.count("irrelevant")))
#print("Prediksi tweet netral: " + str(l_hasil.count("netral")))

num_positif4 = 100*(l_hasil_S4.count("positif")/tweet_test4.count())
num_negatif4 = 100*(l_hasil_S4.count("negatif")/tweet_test4.count())

print("Persentase tweet positif = {:.2f} %".format(num_positif4))
print("Persentase tweet negatif = {:.2f} %".format(num_negatif4))

print('\n')
acc4 = 100*accuracy_score(hasil_mnb_S4,label_test4)
recall4 = 100*(TP4/(TP4+FN4))
specifity4 = 100*(TN4/(TN4+FP4))
precision4 = 100*(TP4/(TP4+FP4))
f1_score4 = 100*((2*TP4)/((2*TP4)+FP4+FN4))

print("Ketelitian = {:.2f} %".format(acc4))
print("recall = {:.2f} %".format(recall4))
print("precision = {:.2f} %".format(precision4))
print("f1_score = {:.2f} %".format(f1_score4))

print('\n')
print(classification_report(hasil_mnb_S4, label_test4))
# Out:
# Skenario tanpa stopword 75:25
# ==============================
#
#
# Jumlah Data tweet_train :  2853
# Jumlah Data label_train :  2853
# Jumlah Data tweet_test :  951
# Jumlah Data label_test :  951
#
#
# Prediksi tweet positif: 417
# Prediksi tweet negatif: 534
# Persentase tweet positif = 43.85 %
# Persentase tweet negatif = 56.15 %
#
#
# Ketelitian = 85.17 %
# recall = 81.51 %
# precision = 85.61 %
# f1_score = 83.51 %
#
#
#               precision    recall  f1-score   support
#
#      negatif       0.88      0.85      0.87       534
#      positif       0.82      0.86      0.84       417
#
#     accuracy                           0.85       951
#    macro avg       0.85      0.85      0.85       951
# weighted avg       0.85      0.85      0.85       951

# %%
f, ax = plt.subplots(figsize=(8, 5))
sns.heatmap(confusion_matrix(label_test5, hasil_mnb_S5), annot=True, fmt=".0f", ax=ax)
plt.title("Confusion Matrix 70:30")
plt.xlabel("Prediksi Label")
plt.ylabel("Label Benar")
plt.show()

# %%
#Convert hasil ke list (hasil tadinya dalam bentuk ndarray)

l_hasil_S5 = list(hasil_mnb_S5)

print("Skenario tanpa stopword 70:30")
print("==============================")
print('\n')
print('Jumlah Data tweet_train : ',len(tweet_train5))
print('Jumlah Data label_train : ',len(label_train5))
print('Jumlah Data tweet_test : ',len(tweet_test5))
print('Jumlah Data label_test : ',len(label_test5))

print('\n')
print("Prediksi tweet positif: " + str(l_hasil_S5.count("positif")))
print("Prediksi tweet negatif: " + str(l_hasil_S5.count("negatif")))
#print("Prediksi tweet irelevant: " + str(l_hasil.count("irrelevant")))
#print("Prediksi tweet netral: " + str(l_hasil.count("netral")))

num_positif5 = 100*(l_hasil_S5.count("positif")/tweet_test5.count())
num_negatif5 = 100*(l_hasil_S5.count("negatif")/tweet_test5.count())

print("Persentase tweet positif = {:.2f} %".format(num_positif5))
print("Persentase tweet negatif = {:.2f} %".format(num_negatif5))

print('\n')
acc5 = 100*accuracy_score(hasil_mnb_S5,label_test5)
recall5 = 100*(TP5/(TP5+FN5))
specifity5 = 100*(TN5/(TN5+FP5))
precision5 = 100*(TP5/(TP5+FP5))
f1_score5 = 100*((2*TP5)/((2*TP5)+FP5+FN5))

print("Ketelitian = {:.2f} %".format(acc5))
print("recall = {:.2f} %".format(recall5))
print("precision = {:.2f} %".format(precision5))
print("f1_score = {:.2f} %".format(f1_score5))

print('\n')
print(classification_report(hasil_mnb_S5, label_test5))
# Out:
# Skenario tanpa stopword 70:30
# ==============================
#
#
# Jumlah Data tweet_train :  2662
# Jumlah Data label_train :  2662
# Jumlah Data tweet_test :  1142
# Jumlah Data label_test :  1142
#
#
# Prediksi tweet positif: 498
# Prediksi tweet negatif: 644
# Persentase tweet positif = 43.61 %
# Persentase tweet negatif = 56.39 %
#
#
# Ketelitian = 84.41 %
# recall = 80.42 %
# precision = 84.94 %
# f1_score = 82.62 %
#
#
#               precision    recall  f1-score   support
#
#      negatif       0.88      0.84      0.86       644
#      positif       0.80      0.85      0.83       498
#
#     accuracy                           0.84      1142
#    macro avg       0.84      0.84      0.84      1142
# weighted avg       0.85      0.84      0.84      1142

# %% [markdown]
# try to applying the model to classify some sentence

# %%
coba = np.array(["terimakasih byu mantap banget dapet kuota gratis cuy"])
coba_vector = tfvec1.transform(coba) 
sentimen = clf_mnb1.predict(coba_vector)
print(sentimen)
# Out:
# ['positif']

# %%
coba = np.array(["anjing bangsat baru kali ini pake operator jaringannya busuk banget"])
coba_vector = tfvec1.transform(coba) 
sentimen = clf_mnb1.predict(coba_vector)
print(sentimen)
# Out:
# ['negatif']

# %% [markdown]
# save the model

# %%
# Nama fike tempat menyimpan data
model = 'model_sentiment_byu_tanpa_stopword.data'
# Siapkan file untuk ditulis
f = open(model, 'wb')
# Simpan data nama siswa ke dalam file dengan perintah dump
pickle.dump(model_mnb1, f)
f.close() # tutup setelah file digunakan

# %% [markdown]
# visualize the word with particular sentiment (positive, negative) with wordcloud

# %%
stop_factory = StopWordRemoverFactory().get_stop_words()
more_stopword = ['enggak','banget','sih','nih','yang','deh','sangat','ini','kalau','buat','kira','s3','oy']
 
# Merge stopword
stopword = stop_factory + more_stopword
 
dictionary = ArrayDictionary(stopword)
r_sw = StopWordRemover(dictionary)

# %%
data['text'] = data['text'].apply(lambda x : r_sw.remove(x))

# %%
label_positif = data[data['label'] == "positif"]

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
text = label_positif.text.values
wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
label_negatif = data[data['label'] == "negatif"]

# %%
text = label_negatif.text.values
wordcloud = WordCloud(
    width = 3000,
    height = 2000,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(text))
fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %% [markdown]
# visualize the proportion of both sentiment (positive and negative)

# %%
sizes = [l_hasil_S1.count("positif"), l_hasil_S1.count("negatif")]
labels = ['positive','negative']
colors = ['chartreuse', 'tomato']
explode = (0.1,0)

#patches, texts = plt.pie(sizes, colors=colors, startangle=-270)

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90, colors=colors)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.legend(labels, loc="best")
plt.show()

# %% [markdown]
# visualize the most word appear in tweets

# %%
positif=data.loc[data.label=="positif"]
negatif=data.loc[data.label=="negatif"]

# %%
positif
# Out:
#                      created_at               source  \
# 1     2020-11-02 08:46:38+00:00  Twitter for Android
# 4     2020-11-02 06:51:44+00:00  Twitter for Android
# 7     2020-11-02 06:03:12+00:00  Twitter for Android
# 9     2020-11-02 05:57:00+00:00  Twitter for Android
# 11    2020-11-02 05:49:47+00:00  Twitter for Android
# ...                         ...                  ...
# 3789  2020-11-30 05:15:16+00:00  Twitter for Android
# 3792  2020-11-30 05:00:57+00:00  Twitter for Android
# 3799  2020-11-30 04:11:50+00:00  Twitter for Android
# 3801  2020-11-30 05:47:12+00:00  Twitter for Android
# 3803  2020-11-30 05:38:32+00:00  Twitter for Android
#
#                                                    text    label
# 1     siang siang kuota gratis kak nindy terimakasih...  positif
# 4           aneh kuota byu ku habis ini bisa pakai haha  positif
# 7                             halo kak nindy cek dm byu  positif
# 9     salah memang pilih provider byu hampir tahun l...  positif
# 11    wow akhir provider internet bebas kamu bikin p...  positif
# ...                                                 ...      ...
# 3789                           positif 0 hari lahir byu  positif
# 3792          asa pakai byu 9 bulan sebentar lahir haha  positif
# 3799                                    terimakasih byu  positif
# 3801  hari sih byupedia kuota tera aplikasi kamu 0 g...  positif
# 3803  para byu kira biar tukar pakai duit bagaimana ...  positif
#
# [1678 rows x 4 columns]

# %%
positiftest=data.loc[data.label=="positif", 'text']
negatiftest=data.loc[data.label=="negatif", 'text']

# %%
positiftest
# Out:
# 1       siang siang kuota gratis kak nindy terimakasih...
# 4             aneh kuota byu ku habis ini bisa pakai haha
# 7                               halo kak nindy cek dm byu
# 9       salah memang pilih provider byu hampir tahun l...
# 11      wow akhir provider internet bebas kamu bikin p...
#                               ...
# 3789                             positif 0 hari lahir byu
# 3792            asa pakai byu 9 bulan sebentar lahir haha
# 3799                                      terimakasih byu
# 3801    hari sih byupedia kuota tera aplikasi kamu 0 g...
# 3803    para byu kira biar tukar pakai duit bagaimana ...
# Name: text, Length: 1678, dtype: object

# %%
tekspositif='\n'.join(positiftest)
tekspositif
# Out:
# 'siang siang kuota gratis kak nindy terimakasih kak byu\naneh kuota byu ku habis ini bisa pakai haha\nhalo kak nindy cek dm byu\nsalah memang pilih provider byu hampir tahun lalu sering tiba kuota gratis\nwow akhir provider internet bebas kamu bikin paket internet semua mau pesan sim kartu\nterimakasih nindy byu\nselamat 6 monthiversary terimakasih kuota gratis sayang byu\ncek dm byu dong\ntahan paket ya kak byu gila good deals\nwow akhir provider internet bebas kamu bikin paket internet semua mau pesan sim kartu\nwow akhir provider internet bebas kamu bikin paket internet semua mau pesan sim kartu\nmau tanya pulsa byu sama telkomsel sama sih di ubah\npunya aku dari byu utuh dong haha lupa melulu tiup\nterimakasih byu gtlt moga tak kecewa gtlt byu\nmemang benar guys kalian pakai kuota bikin makin aman jaya 2 mbps suka jadi paling andal tethering\nbajing telkom lelet byu nyata\nwifi error untung kemarin paket gratis byu\nbyu sambung hidup\nuntung byu hilang sinyal beli pakai akun sama mau beli adik btw byu enggak ada\nsayang sama byu\nbyu selamat saat mati lampu haha byu\nbyu selalu di krusial mati lampu byu\nindosat byu keren aku gratis kuota terus\nmbak nindy datang waktu tepat bilang terimakasih byu\nterimakasih nindy traktir byu\naaaa senang akhir sampai byu\nwow akhir provider internet bebas kamu bikin paket internet semua mau pesan sim kartu\naku pakai byu\nlebih kencang unggah unduh sangar byu\nmemang byu paling erti butuh bisa harga topping jadi permanen\npagi admin mumpung libur yuk cek dm byu\nira trending nindy byu kuota\nyang tren nindy byu bukan\ncombo sakti telkomsel belakang sering tiba hilang ku move on byu terimakasih telkomsel\nkeluarga kena racun byu semua haha tiba minta pesan\nira trendi nindy nya byu nyata nindy masterchefina haha\ncoba paket unlimited byu 1 mbps rasa em mantap\nwow akhir provider internet bebas kamu bikin paket internet semua mau pesan sim kartu\niseng coba byu kali lebih murah kartu halo\nbeberapa hari lalu beli kartu perdana byu shopeeid terus tadi sampai cepat sekali kirim pakai\naku minta 5 ribu isi byu 1gb teman aku malah asih 50 ribu\nadmin cek dm byu\nbaca baca thread kata kuota byu murah terus akhir beli pengin coba tau samarinda jaring enggak\nadmin byu promo 15mb jadi 2mb nya kapan\nbaru tau beli byu sim ejector lumayan\nbyu terima kasih tidak lag hujan badai sayang pokok\nmalam minggu di rumah mama mertua cuaca hujan besar byu lokasi cihampelas bandung\ntunggu kartu sim byu serasa tunggu jodoh alias sabar pengin ketemu\nminta info mana beli kartu byu makassar supirpete2 terima kasih\nharap byu kuota topping khusus quora showroom minat sedikit hanya kelompok orang\nbyu punya telkomsel sekarang liveon punya xlaxiatatbk\ntebing tinggi sumut ada jaring byu\ntetiba sms byu nyata sudah 1 tahun sama moga langgeng terus happy 1st anniversary\nhalo byu mau tanya dong maksud kuota untung apa mohon maaf masih mula haha\nsinyal byu sama kayak sinyal telkomsel\nsayang sama nindy terus kasih bonus anniversary begini ya moga makin langgeng byu\ndm byu eveyhvmmond\ngemas kayak surat byu\nkaget tiba notifikasi kasih kuota gratis 2gb terimakasih banyak byu\nlama lama aku bawa asa sama adminnya byu\nmalam minggu guys kuota libur sama byu nya ready kan tani begadang malam\nbeli byu ambil indomart indomilk terima kasih\nhappy 9 monthiversary byu terimakasih kuota gratis\nsalah anjir post byu tadi deh akun 1 saja\nterimakasih byu btw nindy siapa\nsuka pakai byu kok ada ya 100 ribu unlimited padahal cocok buat ajar\neh baru tau kuota 3 monthiversary byu terimakasih byu\nnindy aku butuh kuota ajar byu\nbyu baik memang\nganti byu nih aku\nnyata 10gb 20 hari per aplikasi enggak habis habis padahal sudah paling ngejos saja sisa ba\nguys siapa sudah sabar tonton bareng virtual konser online here comes the sun goplayindonesia kamu\nenak beli nomor ponsel baru perlu pusing sama hasil undi tipu tipu pinjam abal-abal coba nomor byu ganti\nwow kasih 11gb gratis sana byu kuota jadi tumpah\ncek dm admin byu\nadm ...

# %%
teksnegatif='\n'.join(negatiftest)
teksnegatif
# Out:
# 'apa apa tiba tiba telkomsel hilang sinyal anak nih byu kompak ada sinyal\nsudah laksana marketing bonus turun saya bagaimana dong byu\nbyu ajak ribut kalau mati listrik sinyal hilang\nbyu kemarin lelet benar hhhh\nhalo byu mau isi pulsa belum juga\ntelkomsel masalah apa bagaimana wifi tiba mati eh sinyal byu cuma hsdpa aneh\nadmin byu mau aktivasi login gmail begini melulu sim byu sim 1 wifi mati memang down apa bagaimana\nadmin kok kuota spotify sama youtube bisa pakai padahal banyak byu\ntelkomsel apa apa ini byu sama simpati bisa dua internet\nbyu jelek tumben\nbyu pakai gim rasa ping menang\nbyu tumben buruk kayak indihome sinyal\nhalo byu mau tanya ada pesan sim kartu baru sudah berapa hari lalu kok datang ya mungkin b\nmemang harus kandas kali awal pakai sinyal bagus makin sini makin parah padahal tahun kuota\nmon maaf kok youtube tiktok netflix bisa akses sama sekali byu browsing lelet\nbyu kok lelet anjing\nmau ganti provider kamu macet ml an byu\nandai aku ubah kuota tri byu\nsimpati sama byu jadi alay jam gin\nmemang mesti ganti provider byu makin gila jaring naik turun sering rto sial nya sih\nfull 4g ping 300 byu pubgmobile pubgmobilein\nadmin jaring nya bagus dong masa jelek byu\nbyu sinyal nya bangsat woy\nadmin mau tanya beberapa orang keluh jaring telkomsel susah pengaruh byu bagai informasi aku used jujur\nhalo nindy byu telkomsel kualitas sinyal nya mohon tingkat saking bagus ping nya 0ms jangan\nhalo byu tadi pas buka byu lalu web pc promo 10gb 20 ribu 10 hari pas isi pulsa mau beli kok menu\nsinyal byu stabil padahal di paketin tonton king emyu\nkalian byu user isi pulsa suka susah sih aku isi 7 jam masuk\norang tua byu telkomsel lah kasihan mouse sama keyboard lagi push rank masalah\nadmin byu lapor ganti kartu lama bagaimana mau saing sama tetangga belah\ncek dm byu\nwifi rumah pakai mnc paket data byu ampas parah\nyang punya alam jelek byu\nwoy kantor kamu bakar byu lelet benar\nadmin byu kok ada sinyal begini genting padahal\nmati lampu at least jangan susah sinyal byu\nadmin beli paket kok masuk terus byu di dm detail\nlistrik nyala baru jaring benar bukan cuma telkomsel byu kan\ntelkomsel amp byu bisa internetan cuma 2 saja down semua provider\nbyu sih servis\nbyu enggak sinyal anjay haha\nsinyal byu masalah apa rumah doang\nbyu jaring aco apa bagaimana\naku hilang aku mau hilang sinyal kalian 3careindonesia amp byu jangan lama\ninternetnya byu jelek anjir mati lampu begini aku kerja tugas woy ahelah kesal ingin menang\nbyu kasih kuota gratis soal mati listrik\nbyu jelek pas hujan deras begini doang nyata hm oke\nbyu kok sinyal lo hilang lt3\npakai byu lelet\nmati lampu orang pakai byu bakal rasa hidup kundur 2000 tahun belakang alias ada jaring dong\nada apa byu langsung jatuh jaring haha\nmati lampu nah daerah mana nih sinyal byu ku enggak\nmati lampu byu enggak sinyal byu\ntumben habis hujan sinyal im3 lebih stabil banding byu\nguna game ponsel kadang sinyal tiba drop hilang tiba padahal sinyal baik di mi\nanjing mati listrik sinyal byu hilang\nbyu anjing sinyal jelas tahi\nsinyal byu sama telkomsel ikut macet\njangan pakai byu pasar rumput\nsabar tunggu sim kartu byu datang\nhalo byu beli kuota belum masuk ya\nbyu hujan enggak jadi sinyal jelek\nmantap sabtu kemarin saja begini cc byu telkomsel\nhari sinyal jelek byu\nsekali tes provider baru malah lag kan anjing anjing kamu byu\nbyu ingat\nkayak kartu byu cocok pakai ngegame ping naik turun euy beli paket mahal sama\npakai byu bikin kesal layan komplain lama komplain siang jawab cuma template\nbyu ganggu apa bagaimana masa bisa muat gambar\nadmin telkomsel byu ini sore sinyal jelek sampai h bahkan edge restart ponsel sama\nbyu wifi jelek semua sinyal\nkok sinyal sore hilang byu telkomsel telkomsel ganggu\nhai admin byu dong update aplikasi kok tab kacau\nbyu lelet sebal\nkenapa sinyal byu dadak tiba busuk\nbyu henti surel aku aku ganti telkomsel subsidi kuota kampus bisa pakai byu\nmohon segera tindak lanjut bayar hasil di aplikasi selesai custo ...

# %%
summarize(tekspositif, split=True)
# Out:
# ['aneh kuota byu ku habis ini bisa pakai haha',
#  'salah memang pilih provider byu hampir tahun lalu sering tiba kuota gratis',
#  'selamat 6 monthiversary terimakasih kuota gratis sayang byu',
#  'indosat byu keren aku gratis kuota terus',
#  'beberapa hari lalu beli kartu perdana byu shopeeid terus tadi sampai cepat sekali kirim pakai',
#  'baca baca thread kata kuota byu murah terus akhir beli pengin coba tau samarinda jaring enggak',
#  'tetiba sms byu nyata sudah 1 tahun sama moga langgeng terus happy 1st anniversary',
#  'halo byu mau tanya dong maksud kuota untung apa mohon maaf masih mula haha',
#  'sayang sama nindy terus kasih bonus anniversary begini ya moga makin langgeng byu',
#  'kaget tiba notifikasi kasih kuota gratis 2gb terimakasih banyak byu',
#  'malam minggu guys kuota libur sama byu nya ready kan tani begadang malam',
#  'suka pakai byu kok ada ya 100 ribu unlimited padahal cocok buat ajar',
#  'enak beli nomor ponsel baru perlu pusing sama hasil undi tipu tipu pinjam abal-abal coba nomor byu ganti',
#  'baik kasih kuota gratis terimakasih byu',
#  'aneh byu aku padahal aku lagi ada kuota bisa internetan haha alhamdulillah',
#  'bagaimana cara habis pulsa rp 90 biar jadi rp 0 gatal aku lihat pengin nge 0 byu',
#  'aku beli paket loh akhir pekan byu',
#  'hai byu kuota utama habis apa bisa whatsappan pakai topping',
#  'cinta sama byu kuota akhir bulan ku pol polan',
#  'yuhu terimakasih byu benar 10 hari dan ada 7gb daripada haha kasihan suami baru pasang 23gb 100 ribu 23',
#  'terlalu promo byu asyik anjir pertama beli coba coba doang tahun pakai sesal',
#  'cinta kamu byu punya rekomendasi series yang bagus drama korea boleh hehe biar kuota habis seb',
#  'mau beli byu 50gb mumpung promo takut pakai',
#  'tadi sore asih tau doi byu kuota murah 50gb cuma 100 ribu cuma hari doi kaget langsung beli a',
#  'mantap kali kasih paket data 50gb 100 ribu nah satu 50 ribu 15gb langsung bungkus dua nya terimakasih genks byu',
#  'dulu rekor per bulan pakai kuota cuma 20 30gb pas pakai byu kayak bakal rekor 100gb',
#  'pertama kali tau byu dari teman terus suruh coba kata enak sudah aku coba beli pertama suruh down',
#  'terimakasih byu lumayan 50gb cuma 100 ribu bulan bisa hemat',
#  'byu ada promo 100 ribu 50gb aku banyak kuota',
#  'hai byu aku sim card baru ikut webinar kartu simnya sekitar 3 hari lalu mau aktif vi',
#  'sekarang byu makin banyak paket murah dulu pas aku melarat enggak sekarang alhamdulillah pakai wifi sama',
#  'sumpah nih byu ada promo 50gb 100 ribu doang anjir kuota aku banyak menang mana cuma hari doang',
#  'aku cinta sama byu sudah jalan 9 bulan paling suka dia suka asih hadiah tiap',
#  'mau pakai byu kali pakai referral aku haha wow akhir provider internet yang bebas kamu bikin',
#  'yang pakai byu promo cuma hari doang biasa mah 100 ribu 23gb doang alias layak banget',
#  'byu biasa 100 ribu 23 gb khusus hari dapat 50 gb promo nya kemarin keburu beli',
#  'sayang sama nindy byu 50gb bulan cuma 100 ribu mana kencang sinyal mau menang',
#  'kok aku bisa twitteran kan byu sisa kuota ajar doang',
#  'byu banyak promo aku hidup sama wifi sekarang',
#  'terimakasih byu beli kuota 100 ribu 50gb',
#  'promo kuota byu aku lagi miskin tt',
#  'terimakasih kamu byu kuota murah akhir pekan panjang nya 100 ribu 50gb',
#  'nikmat jadi anak byu tiap anniversary kasih hadiah teman tanya aku pacar sama siapa terus aku jawab',
#  'pengin tau pengin beli kartu byu takut tipu soal pekanbaru ada tengkulak nya',
#  'pengin aktif kartu byu tapi baru beli kuota xl nomor daftar kuota xl',
#  'woy ppppp byu aku baru beli unlimited nya hari ada promo moga moga',
#  'bingung mau beli kuota indosat 32gb 80 ribu promo byu 50gb 100 ribu',
#  'beberapa hari lalu paket habis mau isi byu konek internet dulu otomatis sim 1 aku pakai bentar niat',
#  'baru kemarin beli kuota eh tau byu bikin paket baru hiks sesal deh aku',
#  'anak byu yang mau kuota gratis nih yuk kumpul sini yuk',
#  'byu promo 50gb 100 ribu telkomsel unlimited 75 ribu bulan kemarin habis 130gb pale telkomsel',
#  'gila byu promo kuota long akhir pekan 50gb 100 ribu pikir panjang langsung beli',
#  'nin byu paket bikin kumat habis aku mau beli paket promo akhir pekan paket bikin kumat hangus nin',
#  'mantap admin byu jadi makin betah pakai kartu terimakasih admin',
#  'pas kuota habis memang byu erti aku',
#  'a paket byu terlalu baik segala harga promosi kejut serius biasa pakai as beli kuota 75 ribu cuma',
#  'anjir byu promo terus gapai malah telkomsel aku daftar kemendikbud jancuk',
#  'bisa keluar promo dada byu alias baru kemarin isi kuota',
#  'lah byu promo jangan dada kan jadi beli paket 2 kali',
#  'cuma beli tanggal 28 hari 50gb 100 ribu bulan i love you nindy byu',
#  'baik benar byu tiap kuota habis mau beli ada gratis',
#  'bulan pakai unlimited kuota byu cuma habis gin hitung mending beli 25gb 2 kali lebih murah',
#  'habis isi 20 gagal sekali coba jadi kurang 20 eh apk tambah 40 halal ini admin byu',
#  'kasih kado jadi 3 bulan terimakasih byu ku sayang',
#  'rasa jadi sales byu karena teman tanya paket paling murah enak apa wfh',
#  'cepat sama byu unlimited alias sesal beli paket telkomsel untung promo',
#  'admin byu biar ini cara bagaimana cek aplikasi ada paket ini',
#  'mulai tarik byu 2mbps harga 140 ribu butuh sendiri asli 50gb cukup bulan deh paket telkomsel',
#  'sweet sih byu ucap anniversary 6 bulan sekaligus kasih kuota tau akhir bulan krisis',
#  'haha pakai apn youtube jaring byu jadi aga stabil lah',
#  'siapa di sini pakai paket data 2mbps byu rapat',
#  'admin byu ku kan aku lepas ponsel sekarang lupa taruh nya hilang tau mana mau minta bagaimana cara nya',
#  'sumpah aku cinta sama byu baik bagi kuota gratis doi ulang tahun',
#  'yang tau kuota ajar byu bisa pakai aplikasi apa',
#  'hh kartu byu aku cepat sih aku mau bikin akun baru soal',
#  'guys guys pamer kuota semua mau bikin kamu dong kita kasih tau kamu tipe anak byu bagaimana',
#  'aww senang pakai byu kuota gratis melulu wey guna lagi luar rumah haha',
#  'yuk gabung byu nikmat akses internet super cepat jaring telkomsel kuota internet 34gb cuma 10 ribu',
#  'saya ganti kartu ini tarik sama provider byu moga segera ganti nya',
#  'twitter iklan spotify sama byu aku pakai anjir kok dapat iklan',
#  'aku mau beli paket unlimited byu moga jaring tahi huhu suka ganggu sini',
#  'tahun pakai byu nyata kuota 25gb',
#  'asa 12 purnama nih sama byu tiba asih gratis tau lagi punya kuota',
#  'positif st time pakai byu tak ira kuota 1mbps buat cepat jadi 1mb tau nya kuota unlimited anjir',
#  'guys siapa pernah habis topping youtube 100gb rp 10 ribu tipsnya sama anak byu dong',
#  'asa 9 bulan sama haha byu tetap jadi baik',
#  'sudah gemas sama provider internet nya coba nih byu paket sok far ekonomis tarik bel',
#  'punya nomor byu rencana khusus data paket data telkomsel lumayan tarik jadi bulan ada',
#  'keren memang pakai byu tahun pakai kasih kado terus fitur-fitur baru nya sekarang beli kuota kita',
#  'baru lihat nyata notifikasi byu haha terimakasih sangka 12 purnama sama',
#  'asa 9 bulan jadi sama nindy terimakasih hadiah byu',
#  'buah hormat byu kasih harga internet murah cepat naik yang niat jadi provider',
#  'ampun benar asa 1 tahun sama byu enggak sadar dikirimin kuota begini terimakasih',
#  'byu sama telkomsel lebih bagus mana cepat nya',
#  'hoho nyata 5gb paket bikin nagih byu biasa pakai lumayan 50 ribu 15gb 30 hari',
#  'akhir juga pakai byu nya nyata aktivasi cuma 1 sim di ponsel terimakasih admin',
#  'kemarin sengaja beli topping twitter nya byu pas beli malah pakai indosat terus habis masa aktif toppingnya padahal full hm',
#  'sih jadi aku pakai byu kuota unlimited biasa beli 2500 3 jam awal awal jae ngetwitch sama',
#  'nikmat jadi anak byu untung kapan beli kuota 23gb bonus untung 11 gb lagi promo cu',
#  'ikut aku yang pakai byu aku mau tanya dong',
#  'aaaaak terimakasih admin makin sayang sama byu',
#  'semenjak pakai byu kartu simpati aku cuma isi pulsa goceng biar tetap aktif pengin pindah semua mbankin',
#  'kakak aku tiba masuk kamar omong rip kan kamu sering luar sini aku isi kuota unlimited byu memang kakak',
#  'hey admin byu mau tanya beli pulsa doang masa aktif tambah',
#  'akhir pakai jne waktu kirim sim card byu layan oke kita lihat lah lanjut haha',
#  'beli pulsa tri deh paket ke update sudah ada mau pakai byu deh bulan depan',
#  'teman teman kalian yang pakai provider byu turut kalian oke sih minta ulas dong pilih apa',
#  'mau kuota satu byu yuk beli yuk',
#  'bagai informasi pakai byu paket murah nih cus beli haha',
#  'kamu tau me sok baik laaa terimakasih byu akhir juga punya nomor 666',
#  'cinta sama byu tiba tiba kuota gratis 15gb kuota jadi banyak haha',
#  'selamat pagi anak byu sayang hari senin muram kita mau kasih bikin untung tiap hari kuota 5g',
#  'ah bukan tanggal 15 sih byu kuota aku aktif tanggal 15 soal apa moga tanggal 1',
#  'haha byu baik anjir kuota gratis melulu sinyal kencang',
#  'terimakasih costumer care byu tunggu satu hari akhir balik kuota ku moga depan sistem',
#  'pengin beli promo untung byu kuota 1gb haha',
#  'kuota byu aku habis kenapa bisa pakai',
#  'pakai xl sama 3 tengah hari sudah habis 1gb an pakai byu hemat deh asa kuota banyak',
#  'kuota ajar byu bisa pakai aplikasi platform apa kak boleh tau',
#  'mau pensiun pakai byu ini goda murah jadi sudah haha',
#  'untung aku ingat kuota byu',
#  'pakai paket unlimited kuota cepat 2mbps byu sudah enggak perlu kuota topping bebas str',
#  'mantap nih byu telkomsel atur sendiri kuota cocok aku suka bingung mau isi kuota',
#  'provider byu enak sih pakai siapa ikut aku',
#  'beli ya kuota byu 100 ribu 50gb',
#  'mau dengar cerita kalian dong promo apa yang paling nikmat lama jadi anak byu lama 1 tahun belakang',
#  'habis beli promo byu aku rasa kayak',
#  'nikmat jadi anak byu bangun tidur ku terus promo hari akhir beli kuota bikin betah rumah',
#  'mantap betul 50 gb cuma 100 ribu begitu gratis kuota anniversary romantis sih kamu byu',
#  'guys kamu tim anak byu mana kalau kuota habis',
#  'promo byu tahan benar buat pinang sayang kuota kemarin banyak',
#  'ingat aku besok mau beli paket byu 100 ribu 50gb oke terimakasih',
#  'ampun ampun goda ini tiap promo begini pas aku beli kuota lain buat byu',
#  'wow unlimited byu oke deh pakai jadi hotspot lelet lebih baik tahan simpati',
#  'goda beli live on sudah pakai telkomsel byu sama xl go haha',
#  'halo admin byu pakai paket unlimited ada tambah kuota 10gb kok cepat saya enggak tambah mal',
#  'kau hadir rubah segala jadi lebih indah haha terimakasih kamu byu kau selamat kuota area luar',
#  'masa bodoh byu pas aku beli paket malah promo melulu aksjdiwjwjdksjdjdj',
#  'anjing kuota youtube promoan 10gb 10 ribu byu hilang bajing sesal beli kemarin',
#  'cek untung hari dan langsung banyak cingcong 25gb 30 hari 50 ribu sikat aku cinta kamu byu sok',
#  'bingung habis kuota model bagaimana eh malah kasih kuota gratis anniversary terimakasih nindy byu',
#  'beli paket internet di byu apa ganti nomor kartu atau bisa pakai nomor kartu pertama kali punya',
#  'byu mau macam sama aku kartu as nya aku pegang semua',
#  'kartu byu ajaib haha paket data habis masih pakai',
#  'kabar baik anak byu masa aktif paket habis paling untung hari ada kuota 34gb 95 ribu buat sebu',
#  'tanya dong byu sudah beli kuota 25gb 30 hari kuota ada aktif terus misal mau beli lag',
#  'wow terimakasih banyak nindy bonus kuota 1gb nya happy 3 monthiversary byu',
#  'lancar aku buka youtube terus baru sadar pakai sim 2 byu bukan xl kuota youtube xl ampun',
#  'tau lagi fakir kuota terimakasih byu',
#  'sudah beli kuota baru bonus terimakasih byu sudah tahun cie',
#  'terimakasih memang baik sering sering asih kuota tambah byu',
#  'happy akhir pekan anak byu sayang paling untung hari kita kasih kamu potong harga lebih hemat kak',
#  'admin maksud kuota untung 11gb apa mohon jelas erti aku byu',
#  'byu asyik kalau kuota habis terus mau beli paket potong pulsa kayak telkomsel langsung tebal pulsa nya',
#  'lumayan kuota gratis anniversary byu tahun sama provider',
#  'terimakasih byu sering kasih gratis kuota admin biar makin sayang langgeng terus',
#  'hai anak byu baru sudah siap yang paling untung hari ada kuota 34 gb 95 ribu 30 hari lumayan',
#  'happy anniversary byu kamu baik asih aku kuota tambah 25gb haru',
#  'mantap topping byu jadi kuota reguler haha',
#  'anak byu sarap bukan nasi goreng sarap nikmat pakai kuota bikin untung tiap hari menu spesial',
#  'admin kuota untung apa ya byu',
#  'baik byu asih kuota anniversary reward paket murah makin lama pakai kok makin lelet paket hilang',
#  'pakai provider byu beli pulsa konter biasa sih apa lewat indomart ovo',
#  'yang pakai provider byu sini mau tanya',
#  'terimakasih kuota gratis jangan sinyal penuh 4g tapi internet lelet byu',
#  'kaget tiba mas jne antar paket asa beli apa telah bulan nyata terimakasih byu',
#  'guys akhir aku beli paket byu hehe',
#  'siang kak byu mau tanya paket topping bisa pakai telpon nomor telepon rumah',
#  'anjir byu 25 ribu 50 aku baru isi paket anjir',
#  '117gb banyak pakai paket apa ya pengin beli paket byu pulsa tri aku banyak tetap',
#  'pokok aku mau goda sama promo paling untung hari dari byu 2mbps bulan cuma 120 ribu pokok',
#  'tengah malam tadi bangun ecek byu promo 2mbps 1 bulan 90 ribu khusus 18 november bisa langsung beli enggak pulsa sama',
#  'hari sih byupedia yang baru move on byu mau ingat segera aktivasi sim kartu kamu kar',
#  'aw happy 9 monthiversary aku sama kamu byu terimakasih kado cinta',
#  'entah promo apa byu 100 ribu paket 34gb loh biasa 23gb deh',
#  'siapa pakai byu ku mau tanya haha',
#  'mantap 25gb cuma 50 ribu byu aku langsung beli haha',
#  'yey kuota bikin untung tiap hari 30 hari 2mbps 30 hari kamu aktif loh pakai byu mohon bantu',
#  'yuk pakai byu beli unlimited 2mbps hemat 50 ribu',
#  'bingung mau terus pakai unlimited byu ganti provider',
#  'yang pernah beli kartu byu online berapa hari sampai rumah nya',
#  'beli kuota 50 gb byu tau bakal habis enggak',
#  'yang pakai kartu byu cara lihat masa tenggang bagaimana',
#  'yang tau cara topping ajar byu jadi kuota utama kuota apa kayak sayang masih banyak bentar',
#  'pernah pakai paket data yang ini guna byu',
#  'pakai byu cuma beli kuota twitternya',
#  'yang pakai byu mau tanya tanya dong',
#  '5 jam mantap untung aku pakai byu unlimited jadi cemas sama kuota tinggal akses doang',
#  'a6 aku kuota gratis byu',
#  'pengin ganti kartu byu nanti dapat kuota kemendikbud haha',
#  'byu promo 5gb 15 ribu haha jadi pakai kuota wifinya dimatiin',
#  'kuota 65gb bulan pakai apa ini byu 35gb harus habis 10 hari',
#  'pakai byu layak enggak aku mau coba enggak paham haha',
#  'rugi aku pakai byu',
#  'begitu aku mau beli kuota topping twitter byu',
#  'pakai byu paket unlimited 1 mbps unduh enak sih',
#  'gara-gara beli kartu byu eh lupa ganti surel akhir malah surel yang taruh ponsel aku sayang sayang mau beli bilang',
#  'byu promo melulu kuota aku 10gb',
#  'yang pakai aplikasi byu tolong mau tanya',
#  'pakai provider byu ulas dong',
#  'guys yang pakai byu',
#  'aku jadi tarik pakai byu',
#  'btw gara-gara kemarin byu asih kuota 25 gb sekarang bingung mau habis 8 hari baru pakai 3 gb',
#  'moots yang pakai byu itu kuota enggak mau beli masih maju mundur',
#  'byu mau promo topping apa sudah mau habis tapi aku stream trejo',
#  'mau beli kartu byu pikir nya 1 hari 1 malam gilir dp kaya begini gerak cepat dasar aku',
#  'kartu byu bagus sih pengin pakai',
#  'mau beli nomor byu yang pernah coba',
#  'byu memang baik sekali aku kuota anniversary lumayan',
#  'percaya sama indihome aku ganti paket data byu di sadar dua punya telkomsel',
#  'yang tukar pulsa sih aku salah beli pulsa byu malah isi ke indosat',
#  'mau tanya yang pakai byu bagus',
#  'apa ganti pakai byu ya',
#  'terimakasih byu akhir kartu aku ueueue',
#  'kabar baik anak byu suka isi kuota hari promo paling untung hari ada kuota hari 15gb rp 10 ribu',
#  'iya baru ingat cuma mau tawar kalian sapa tau minat pakai provider byu telkomsel paket data nya mu',
#  'byu ada niat asih kuota anniversary aku apa',
#  'provider byu rekomendasi sih pengin ganti kartu buat paket data',
#  'mending pakai byu mana aku bulan sd sekarang 63gb bingung bantu pilih terima kasih',
#  'nindy siapa yang aku tau cuma nindy byu',
#  'byu tau kuota habis promo 100 ribu 50gb cuma hari',
#  'serius tanya sini yang pakai provider byu sih hemat bagus penasaran haha',
#  'terimakasih kamu byu sia sia aku paket 10 ribu hari padahal tadi marah lelet panik',
#  'baik makin cinta sama kartu byu terimakasih banyak',
#  'tau lagi punya paket aku cinta byu',
#  'pakai kuota byu enak beli unlimited yang gb ya',
#  'sini yang pakai byu mau pakai maju mundur soal sinyal telkomsel tempat aku bagus pengaruh ya',
#  'kuota byu 2gb telkomsel 10gb terimakasih kemendikbud aku jadi perlu beli kuota',
#  'yang pakai provider byu mantap',
#  'byu kuota ajar enggak',
#  'lelet ku yang pakai byu',
#  'byu paket 1 hari 10gb cuma 10 ribu lumayan kalau penting tiba provider pertama wifi enggak sinyal',
#  'p p p moots pakai byu terus pakai paket unlimited yang mau tanya ini cepat lelet apa a',
#  'aku anak muda pakai byu',
#  'halo admin byu cara sim kartu baru nomor sama bagaimana cara apa syarat',
#  'promo by 50gb ada hari byu',
#  'urus provider aku paling cocok sama byu kuota jelas harga murah sinyal tara telkomsel kare',
#  'byu promo kuota topping 10 ribu 10gb 20 hari dong sungguh bantu ekonomi',
#  'buat anak byu hobi beli kuota hari paling untung hari sedia kamu paket bikin aman jaya',
#  'admin kuota apa byu',
#  'guys yang pakai provider byu',
#  'kartu byu unlimited sudah habis bisa whatsapp sama twitter',
#  'lah paket unlimited byu enggak menang aku kulon bagaimana',
#  '50gb 100 ribu besok admin aku streaming mv btstwt haha byu',
#  '4 hari mau anniversary sama byu kasih apa aku admin',
#  'byu ada promo 50gb 100 ribu enggak',
#  'yang pakai byu ayo sini cerita siapa tau aku tarik',
#  'nindy byu terima kasih suka kasih kuota tiba kan aku jadi senang',
#  'jadi pengin coba pakai byu',
#  'yey kuota gratis byu terimakasih',
#  'kemarin aku lihat byu 10gb youtube cuma 20 ribu kok sekarang ada',
#  'btw pakai byu sekarang jadi telkomsel',
#  'baru tau byu set sendiri mau beli kuota berapa jangka waktu lama apa',
#  'coba beli kuota byu 15gb cuma 10 ribu dan laku hari doang',
#  'nindy terimakasih akhir kulon aku aman byu',
#  'ganti kartu aku byu enak sih',
#  'sini yang pernah beli byu nomor ambil indomart aku mau tanya dong',
#  'siapa pakai kartu byu',
#  'happy 9 monthiversary byu btstwt aku kasih kuota buat stream mv kamu',
#  'terimakasih nindy kuota monthiversary nya jadi makin sayang byu',
#  'terimakasih byu zoom hari lancar sekali nyata aman ngezoom pakai paket 2mbps',
#  'kalian yang pakai byu mau tanya dong',
#  'paling untung 50gb 100 ribu kapan lagi aku butuh alias kemarin bimbang mau beli apa byu',
#  'semenjak beli paket 50gb byu aku jadi hobi tonton film',
#  'happy monthiversary sayang byu terima kasih kuota nya',
#  'pakai byu jaring nya bagus',
#  'besok promo byu mau beli kuota sekarang takut tiba besok promo',
#  'aku mau ganti kartu byu masih cinta sama telkomsel',
#  'pakai byu 50 gb kok habis biasa sampai bulan kuota habis',
#  'ppppp byu kamu isi aku kuota 10 gb',
#  'mau tanya pakai kartu byu',
#  'yang pakai byu dong suka duka',
#  'yang pernah lagi pakai provider byu indah',
#  'terimakasih byu tau aku malas beli pulsa asih gratis 2gb huhu sayang',
#  'byu jaring nya bagus sih mau pakai',
#  'byu tau deh asih promo pas paket aku mau habis',
#  'beli byu 50gb 100 ribu jalan ninjaku 50gb nya telkomsel 181k',
#  'tiba kuota 1 gb byu',
#  'byu baik asih kuota gratis',
#  'aku beli kuota byu',
#  'eh pakai byu hari ada promo 25mbps 30 hari unlimited',
#  'aku mau pindah byu ah hihi',
#  'oi pakai byu murah sih',
#  'tanggung admin aku tantang byu ada 5mbps 200 ribu 30 hari aku beli',
#  'kuota untung byu promo beli jangan',
#  'pakai byu juga',
#  'mau beli kuota byu eh tiba kuota kemendikbudri',
#  'pakai byu bagus',
#  'pakai kartu byu ulas dong moots aku tiba pengin beli doi',
#  'pakai kartu byu aku mau tanya dong',
#  'terus aku isi byu apa enggak pindah ponsel',
#  'lanjur kemarin buru beli kuota byu aku',
#  'yang pakai byu di sini kasih tau aku jaring bagus haha serah sama telkomsel',
#  'yang pakai kartu byu',
#  'yang pakai kartu byu',
#  'byu bikin kuota topping youtube 10 gb enggak',
#  'terimakasih byu lo jual paket unlimited kuota aku menang pakai tonton live jam 4 tadi sore',
#  'beli kuota tapi tetap enggak yang chat byu',
#  'byu promo kapan kuota aku mau habis',
#  'untung aku pakai byu jadi perlu khawatir kuota cepat habis tunggu a naik hashtag nya yuk secret',
#  'kartu byu mantap deh padahal aku pakai paket unlimited bulan batas cepat maksimal 2 mbps',
#  'kuota byu habis shit',
#  'kok aku giur pakai byu',
#  'tebak admin bayar pakai apa coba byu',
#  'jarang lancar 720p pakai paket data 2mbps byu',
#  'pakai byu ada sinyal',
#  'pakai byu enak sih',
#  'pakai byu enak sih',
#  'habis beli promonya byu',
#  'pakai byu kuota gratis',
#  'sini yang pakai byu ya mau tanya tanya',
#  'mau ganti byu sayang simpati nya kuota gratis enggak pakai',
#  'untung beli paket byu baru 34gb haha jf streaming',
#  'asa sudah 6 bulan terimakasih sayang byu',
#  'semenjak kuota paling untung hari beli nya paling untung terus yang 100 ribu 50gb byu',
#  'kalian yang pakai byu',
#  'kalian yang pakai byu',
#  'sama makanya pakai byu',
#  '9 bulan sama byu',
#  'aku byu error nyata kuota habis haha',
#  'ikut aku yang pakai provider byu',
#  'terimakasih admin nindy kuota gratis hihi sayang enggak asa lama pakai byu ganti pr',
#  'asyik ye pacar sama byu 3 bulan sekali kasih kuota haha',
#  'nyata kuota ajar telkomsel habis untung kemarin iseng beli byu',
#  'baru tau sekarang byu bisa beli pakai shopeepay',
#  'malam habis kuota byu jam 0055 paket habis',
#  'promo hari by byu tunggu 50 ribu 30gb haha',
#  'kalian pakai byu sinyal nya lancar',
#  'pakai byu 100 ribu 50gb',
#  'dong byu kuota 50gb nya keluar kuota aku habis',
#  '3 bulan ini sama byu terimakasih kuota gratis',
#  'asyik pakai byu paket hari yang unlimited terus murah',
#  'terimakasih byu jadi aku tonton youtube 720p lebih',
#  '2 mbps maksud bagaimana mau coba pakai byu',
#  'cie tau kuota mau habis pas tanggal tua byu']

# %%
summarize(teksnegatif, split=True)
# Out:
# ['telkomsel masalah apa bagaimana wifi tiba mati eh sinyal byu cuma hsdpa aneh',
#  'admin kok kuota spotify sama youtube bisa pakai padahal banyak byu',
#  'halo byu mau tanya ada pesan sim kartu baru sudah berapa hari lalu kok datang ya mungkin b',
#  'mon maaf kok youtube tiktok netflix bisa akses sama sekali byu browsing lelet',
#  'memang mesti ganti provider byu makin gila jaring naik turun sering rto sial nya sih',
#  'admin jaring nya bagus dong masa jelek byu',
#  'admin mau tanya beberapa orang keluh jaring telkomsel susah pengaruh byu bagai informasi aku used jujur',
#  'halo nindy byu telkomsel kualitas sinyal nya mohon tingkat saking bagus ping nya 0ms jangan',
#  'admin byu lapor ganti kartu lama bagaimana mau saing sama tetangga belah',
#  'admin byu kok ada sinyal begini genting padahal',
#  'admin beli paket kok masuk terus byu di dm detail',
#  'internetnya byu jelek anjir mati lampu begini aku kerja tugas woy ahelah kesal ingin menang',
#  'mati lampu orang pakai byu bakal rasa hidup kundur 2000 tahun belakang alias ada jaring dong',
#  'byu hujan enggak jadi sinyal jelek',
#  'kayak kartu byu cocok pakai ngegame ping naik turun euy beli paket mahal sama',
#  'admin telkomsel byu ini sore sinyal jelek sampai h bahkan edge restart ponsel sama',
#  'kok sinyal sore hilang byu telkomsel telkomsel ganggu',
#  'byu sama tri di rumah aku lebih cepat tri jaring',
#  'jaring byu makin sini kok makin lelet sih',
#  'lagi hujan begini hawa pengin kelah sama sinyal byu',
#  'pasang wifi tau tadi kartu byu bagus jadi susah jaring goblok sekali',
#  'sinyal byu jadi jelek begini buka twitter ig youtube google padahal whatsapp sama tele lancar baik dong',
#  'dear byu di daerah rumah sinyal bisa pakai padahal bawa mana mana aman',
#  'capek baru sadar tadi malam gmeet pakai byu padahal niat mau pakai telkomsel biar kuota gmeetnya pakai menang makin untouchable itu kuota',
#  'produk telkomsel suram habis indihome byu jangan main game buka ig enggak muncul apa apa anjing mahal doang',
#  'admin sinyal telkomsel sama byu ganggu 3 hari sinyal cuma 2 bar doang padahal sudah di atur lte',
#  'bangkai aku mau live streaming jurnalrisa buffering melulu sinyal jelek byu',
#  'sinyal full kok pakai game nge lag byu pakai sosial media oke cuma begitu kurang mantap jadi',
#  'sinyal byu kok makin sini makin jelek di baik',
#  'sekarang kok lelet sih padahal unlimited 2mbps loh byu',
#  'baru tahun pakai byu bulan aktif kuota sekali beli kuota 15gb 50 ribu tidak internet koneksi what the hell',
#  'padahal beli topping youtube 10gb kenapa bisa buka murka byu',
#  'sesal beli kuota youtube byu bisa pakai anjir',
#  'kartu byu pakai main game lelet',
#  'nindy byu ikut cuti sama dm malam ada balas mau tonton premier video enggak b',
#  'dear telkomsel byu sekarang kalian jaring lelet sih 3 hari begini sekar',
#  'pakai main game macet tiap hari bikin kalah melulu byu',
#  'telkomsel byu memang sinyal kayak anjing apa bagaimana aku chatin kawan pakai telkomsel enggak kirim chat aku enggak kirim',
#  'kalian masalah apa telkomsel byu sini cerita alias lelet astaga',
#  'hey byu akhir akhir jaring lelet sinyal suka hilang hilang',
#  'halo byu ya tiap jam gin jaring down terus dm enggak di balas hehe',
#  'unduh berkas pakai byu kok lelet ya cepat naik turun 600kbpsan tadi pakai simpati lancar 2mbps',
#  'byu semenjak banyak pakai jadi lelet kayak siklus indie makin mainstream makin enak',
#  'guiseee beli pulsa aku dong aku niat isi telkomsel sisa transfer byu eh nyata bisa don',
#  'pakai kartu byu mahal jaring nya bagaimana',
#  'aku tonton youtube sama viu kok sedot malah kuota utama byu',
#  'emosi lama pakai byu makin hari sinyal makin jelas di musim hujan kayak begini',
#  'apa mau panjang 50gb 100 ribu nya byu aku lupa beli nya',
#  'byu error apa sinyal jelek dari tadi',
#  'tadi twitter memang ara ganggu apa sinyal tri sama byu lagi beres',
#  'mencak sinyal jelek nyata memang down maaf aku byu',
#  'admin ya beli topping youtube twitter kok jadi sering server error byu',
#  'allah sinyal telkomsel kok begini byu jaring bagaimana dong',
#  'lebih asli euy byu nerf di tempat orang parah sekali sinyal ari pakai telkomsel lancar jaya',
#  'apa kabar byu sinyal kok jelek hari',
#  'jelas sinyal kamu lelet aku ganti kartu byu',
#  'admin byu paket 10gb 20 ribu 10 hari kok kata guna baru cek tab reward enggak ada',
#  'promo byu hari doang elah mau beli kuota ada',
#  'btw sinyal byu kok jelek ya pas ganti telkomsel kok bagus',
#  'aku kesal sama byu allah baru promo 50gb 100 ribu pas aku beli kuota',
#  'siang admin byu mau tanya tadi transaksi pulsa lewat aplikasi linkaja kok masuk terimakasih',
#  'nindy byu jaring eror sudah jam bisa ini harus tunggu aku dom sulawesi nindy pagi',
#  'apa sudah wifi ganggu by lelet kenapa biasa kayak begini byu',
#  'byu 2mbps hujan jelek astrala join kelas online jadi bisa ke leave sendiri terus sebal aku',
#  'kenapa hari kok jaring busuk ya asli byu padahal lte',
#  'bagaimana maksud byu foto sama caption beda beda benar mana iya 10 ribu aku beli',
#  'admin byu kok aplikasi ada sesuai iklan 20 ribu 10gb 10 hari',
#  'admin baiiii byu kuota youtubeku pakai ini baru beli buat buka youtube enggak bisa',
#  'admin byu anak lama kok dapat kuota 10 gb untung 5 gb harga 50 ribu promo anak baru ya',
#  'pakai 3 sinyal byu 1 bar doang mana naik turun aku kulon heh',
#  'tarik coba byu 140 ribu unlimited 2 mbps kok lihat komentar fb banyak keluh lelet jadi ragu mau beli',
#  'telkomsel byu tri xl smartfreen indosat indihome jelek di lokasi aku anjir',
#  'sumpah byu ada jaring sama sekali anjir',
#  'admin dapat kuota 9 bulan byu kok bisa pakai internet sama kuota ig masih bisa pakai',
#  'by kenapa mati lampu sinyal ikut mati byu aku kirim gagal terus entah kirim enggak',
#  'permisi admin akhir sinyal lelet ya mau komplain lewat pesan enggak kirim byu',
#  'rasa kok byu makin hari makin sama kayak indihome kecewa titik',
#  'tanya live chat hari apa ada tanggap sama sekali hehe byu',
#  'nomor aku byu kok internet nya macet padahal kuota aman',
#  'beli kuota topping youtube kok bisa buka youtube sama sekali byu',
#  'byu apa kok jadi lelet sekali',
#  'jaring byu kayak anjir tau aku mau ngebucin apa',
#  'edan byu lelet pakai padahal sinyal 4g',
#  'kenapa jaring byu 3 hari lelet mampus',
#  'sinyal byu sih ada paket kok bisa internetan sama sekali',
#  'kok jaring byu lelet',
#  'beli kuota topping youtube byu percuma pakai sesal mah 10gb salah sih kasih terang',
#  'allah telkomsel byu kalian kompak deh macet pindah provider cari koneksi stabil eh malah lebih parah waduh',
#  'admin byu kenapa beli topping instagram 6 oktober 20 tiap pakai instagram malah sering potong',
#  'halo byu makin lama kok sinyal makin jelek',
#  'sumpah byu jadi jelek sinyal nya menang',
#  'nin byu pakai topping youtube ada kuota utama kok bisa pakai',
#  'lelet sumpah aku mau uji byu',
#  'ini tepat kembali mulai ribut hey telkomsel byu sinyal kalian ada yang benar',
#  'p byu kok kuota youtube enggak pakai',
#  'unduh game 2gb doang pas 1gb gagal melulu terang masalah jaring betul anjing byu',
#  '5 hari sinyal byu suka hilang an sekali muncul 4g kadang suka lelet ya admin mohon bantu',
#  'byu mati lampu sinyal lelet mau komentar bumi datar padahal tadi malah loading',
#  'luar kost sinyal 4g masuk kamar langsung edge byu kok begini sih',
#  'wow byu aku ada sinyal terus telkomsel aku h bagaimana',
#  'sering lihat iklan ini pas cek apk kok ada admin byu padahal minat',
#  'aku tiap cek dm cuma komplain admin grab sama byu doang',
#  'byu ada sinyal ada jaring tugas aku tau bakal kayak mana kemarin jadi 5 jam kenapa gapai gara-gara sinyal',
#  'byu cek dm ada jaring deh lama ganggu melulu rugi begini terus',
#  'ganti kartu apa aku sinyal jelek padahal pakai telkomsel indihome byu ada benar',
#  'ish sinyal jelek sih byu jam 11 siang sekarang masa cepat paling kencang 38 kbps mahal enggak',
#  'admin byu cek dm bulan akhir koneksi internet sering stabil padahal sinyal bar full 4g cepat',
#  'aku ganti provider byu kok sinyal jelek di sini',
#  'makin sini byu makin lelet aku aku pakai sinyal telkomsel doang',
#  'indihome telkomsel byu lelet semua padahal sinyal 4g pakai aku tuh',
#  'kartu byu kok akhir sinyal bagus terus',
#  'kenapa byu aku ada sinyal mana mati lampu',
#  'halo byu mohon bantu beli kuota besar 085157105229 sinyal naik turun 4g 3g koneksi ikut',
#  'jaring byu tiap jam 10 malam dimatiin kayak bot menfess bagaimana tiap jam 10 langsung tiba jadi h 140 ribu kok begini',
#  'sih sinyal kemarin jelek byu',
#  'hai kak mau tanya aku pas mau registrasi kok bisa ada terang kakak temu padahal tidak kakak benar byu',
#  'mau tanya dong kok topping youtube enggak guna awal padahal kuota utuh byu',
#  'mau beli promo byu 50gb 100 ribu percuma sinyal rumah sekarang jelek enggak kayak awal pakai dulu',
#  'cek twitter eh benar telkomsel sama byu bodoh percuma sekarang 4g enggak jalan apa',
#  'beli paket kayak begini tulis 2mbps kata tonton youtube 480fps situ mau bikin hoax byu',
#  'pakai byu rasa sih sekarang jaring parah super lelet kayak keong padahal pakai paket',
#  'sinyal byu kok sekarang lelet ya',
#  'bagaimana kok aku beli kartu byu sama paket pas aktif ada paket data',
#  'yang pakai byu sinyal lemah sih malam',
#  'nindy padahal baru anniversary tahun kenapa kamu bikin aku sebal sinyal sore sering hilang terus tau byu',
#  'iseng beli unlimited byu buat keluar sebentar biar kuota eh nyata sama bohong ada internet',
#  'byu masalah apa sih ya subuh sekarang sinyal hh doang',
#  'jaring kamu sayang kok jelek akhir ada masalah hm byu',
#  'sumpah aku pakai byu unlimited lelet parah ccd biasa begini lama semua provider sama',
#  'admin byu kok aku bisa aktivasi nomor',
#  'sinyal kamu jelek kenapa byu',
#  'halo byu kok sinyal hilang apa enggak paket',
#  'kartu byu pakai jobstreet sama indeed memang jaring lelet ya',
#  'kecewa sih parah sim 1 pakai kartu as telkomsel sim 2 pakai byu jaring lelet sudah kayak l',
#  'aku bingung dari kemarin ada sinyal bagus sini im3 sama byu main pubg ping 200an coba xl tapi',
#  'ppppp byu apa ada sms notifikasi pas paket tip mau habis macet macet bingung tiba connect tau kuota habis',
#  'kecewa sama byu awal internet lancar kuota banyak loh lelet parah baik internetnya',
#  'asa kok jadi boros admin padahal baru isi kuota byu',
#  'dong bapak ibu mas mbak byu sinyal rumah mentok 500 kbps doang padahal beli cepat 1 sama',
#  'sinyal byu telkomsel kayak ampas haha ampas anjing',
#  'sih 2 hari sinyal kalian hancur telkomsel byu enggak usah suruh ganti apn amp suruh rest',
#  'ya sekarang byu buat main pubg game sinyal jadi jelek bagus kayak huf padahal 4g',
#  '2 match akhir sinyal lelet patah patah melulu aneh stabil emosi jadi kalah byu 3 hari loh ah gab',
#  'sinyal down apa bagaimana kok h byu',
#  'admin jaring ya kok ada sinyal byu',
#  'kalian pakai byu telkomsel alami ganggu sinyal apa akhir akhir',
#  'apa aku doang rasa telkomsel sama byu sinyal hancur parah gila minggu sudah lewat kelas zoom',
#  'telkomsel sama byu sinyal jelek dari kemarin ggggrrrr',
#  'admin sinyal aku kok jelek sudah 3 hari 3g tidak service bagaimana byu biasa enggak begini',
#  'byu telkomsel segala jenis malam jangan hilang sinyal ya aku tuh tiap rabu sama kamis',
#  'pengin unggah tiktok padahal enggak sinyal melulu anjing byu sih',
#  'halo byu kok lelet ada apa tolong sinyal down melulu',
#  'serius ini byu memang masalah bagaimana kok sinyal aku hilang hilang an melulu',
#  'sinyal byu tiba busuk aku mau ngwar 1111',
#  'sesal baru beli paket byu sinyal full lag pakai jadi',
#  'sinyal byu sisa 7 gb lelet minta ampun dari 15 gb 7 gb kayak lancar makin sini',
#  'selamat pagi admin byu mau beli paket data lama minta ampun aplikasi update malah benar ada lagu segala',
#  'admin kok paket data reguler enggak pakai main game byu',
#  'habis beli paket bikin untung kok masuk admin byu',
#  'halo byu saya baru beli paket puas 2 mbps kayak minggu jaring lelet ketulungan',
#  'internetku doang apa bagaimana indihome enggak byu sama lelet',
#  'byu kok lelet ada apa gerangan',
#  'admin cek dm byu ada kendala masa jaring internet kayak biasa',
#  'byu jelek sinyal allah mau kerja tugas',
#  'admin kok hari koneksi jelek ya mohon bantu byu',
#  'telkomsel sama byu kenapa kayak aku bayar mahal jaring lelet bangsat wawancara tiba koneksi',
#  'ya belakang koneksi byu kok jelek ya kayak waktu pertama beli banyak rto nya ganggu',
#  'mau kapan kayak begini benar kali biar aku lancar kerja tugas ehem byu',
#  'sekarang telkomsel tempat aku sinyal bagus kayak sama bohong aku pakai byu lelet',
#  'byu kenapa akskskshakak aku di lantai pun sinyal ada',
#  'kok lelet jaring byu telkomsel',
#  'admin byu kuota lelet aku ambisi nya',
#  'admin apa kok jaring ada terus jalan internet nya byu pakai tethering mama mentwitt',
#  'byu ku lelet aku kesal',
#  'byu sih sinyal jadi jelek heran',
#  'byu sih aku twitteran bisa hiks anjir deh',
#  'aplikasi kok begini terus admin byu',
#  'woi byu jaring kok tambah lelet ini',
#  'ikut aku yang kartu pakai byu hiks jelek ya allah sinyal',
#  'sinyal byu tempat ku parah sekarang jelek nya ih',
#  'byu kok kemarin bisa pakai main pocket camp jaring nya sih',
#  'jaring byu kok lelet sih banjarmasin',
#  'duh pakai telkomsel kok lelet sih pakai byu busuk ampun buka story whatsapp lama bale',
#  'nindy kenapa lag jadi menang 1111 sinyal hilang melulu sempat h malah sempat ada sama sekali byu',
#  'woy ikut aku pakai byu ganggu mau buka kartu bisa',
#  'admin kok main game jaring jelek padahal full loh jaring youtube twitter ig lancar byu',
#  'tuh kan benar rumah aku malah ada sinyal pakai byu gilir pakai eks el lancar jaya',
#  'ih kuota byu aku youtube pernah pakai',
#  'byu kok jadi lelet hujan',
#  'sih sinyal 4g enggak buat main game byu',
#  'lah byu harus pilih nomor begini aku bisa pakai nomor sendiri',
#  'minta ini kuota byu ku kok whatsapp sama ig an apa o spotify tadi tiba enggak bisa tapi sekarang bisa',
#  'aku lihat komparasi 3 sama byu sih scoring kata jadi dari kemarin lelet wahai',
#  'yang tau sih jadi aku beli sim kartu byu registrasi sinyal data aktif enggak hubung internet',
#  'ponsel aku jelek apa byu kemarin ada sinyal',
#  'telkomsel tiap hari lelet byu pengaruh satu jaring aneh semua',
#  'byu kamu kok lelet',
#  'asli kenapa byu aku ada sinyal',
#  'pakai byu memang ganggu apa bagaimana',
#  'byu ganggu apa bagaimana lelet sumpah buka twitter ada gambar',
#  'byu kenapa anjing lelet',
#  'sinyal byu memang jelek apa bagaimana',
#  'sinyal byu lama makin lelet ah kesal',
#  'nyata pakai byu sinyal h buffering terus jadi',
#  'sinyal byu kok lelet tumben',
#  'byu kok jelek sih sinyal tumben',
#  'oyyy byu sih akhir sinyal jelek lelet masya allah',
#  'telkomsel sama byu sih lelet dua',
#  'ya minggu ada masalah apa sinyal full enggak jalan sama sekali bikin emosi tolong banget darurat byu',
#  'mau kirim jawab uji tiba koneksi byu malah lelet padahal sinyal full alhasil timeout',
#  'byu sinyal jelek kenapa',
#  'baru pakai byu nyata macet game enak an kartu telkomsel lain apa cuma aku',
#  'byu jelek sinyal aku buka game buka melulu',
#  'kartu byu aku apa bagaimana lelet tolong',
#  'sinyal tri hilang tethering byu eh data mepet beli dulu pakai lah eh verifikasi code nya kirim sms dong',
#  'kurang so sweet apa aku sama byu kenapa balas balas',
#  'coba pakai 1 sim kartu nih pakai punya byu tetap begini peak biasa sinyal 3g nya jelek gu',
#  'pakai byu begini melulu astagfirullah padahal lihat sinyal full 4g',
#  'aku sesal beli byu mana isi nya lag 100 ribu enggak pakai koneksi nya kayak tahi setan benar',
#  'masa byu kalah sama triindonesia soal ngegame mau pakai tri soal listrik mati sinyal hilang ba',
#  'kalau lagi main rank sinyal jangan kayak begini dong byu',
#  'pakai byu bikin stres doang sinyal jelek',
#  'kuota by ku kok tiba hilang admin kemarin 40 gb an padahal byu',
#  'bayu sinyal lelet kenapa byu',
#  'ponsel aku byu indihome masalah apa sama vlive baru pakai kuota crash melulu pakai wifi on loop kelar',
#  'apa byu kok lelet',
#  'sinyal byu lelet pas selesai hujan v',
#  'admin jaring nya lte lelet byu',
#  'koneksi lo kenapa jangan kasar mulut aku byu telkomsel apa jadi gab',
#  'sinyal aku jelek byu sahabat tasik',
#  'bagaimana byu jaring kok stabil',
#  'astaga byu kenapa kok ada sinyal tiap habis hujan',
#  'admin byu 10gb 1 hari nya kok hilang',
#  'twitter sih aku ganti jaring indihome xl byu tetap bisa putar video ponsel nya ih',
#  'byu kok tumben sinyal jelek',
#  'byu main game hancur axis sinyal hilang waduh anjing serba salah aku pakai provider 2020 ada benar sem',
#  'halo byu aku habis isi pulsa 10 ribu hari harus pulsa ku sekarang 11 ribu kok pas cek aplikasi',
#  'sinyal hari h melulu byu',
#  'halo byu kok jadi lelet deh jaring',
#  'sinyal rumah aku tuh kayak tahi padahal byu punya telkomsel 4g doang enggak apa',
#  'byu lelet sih kemarin kok punya hilang hilang sinyal nya',
#  'telkomcare telkomsel byu kompak deh sinyal malam hilang bisa internetan',
#  'bisa lebih jelek sinyal byu',
#  'bagaimana nindy byu sinyal parah jelek awal awal pas beli bagus mantap koneksi pe',
#  'sumpah byu kemarin sih internetan bisa padahal kuota ada',
#  'aku saran mau push rank jangan pakai byu ping stabil ning simpatiloop deh walaupun sama telkomsel',
#  'kok byu pas hujan jelek ya sinyal',
#  'kenapa akhir sinyal nya lemah terus byu',
#  'mau tanya dong guys adik aku baru mau beli kartu byu benar paket unlimited sih terus main game lelet',
#  'byu telkomsel sama anjing',
#  'mood aku jelek lo byu jangan kayak anjing',
#  'aku telpon 606 kok bisa pakai byu',
#  'ih atuh byu rumah aku tetiba sinyal lelet',
#  'pakai kartu byu jaring payah sesal beli paket',
#  'tiba tiba ada sinyal anjing telkomsel byu',
#  'aku kok bisa aktivasi kartu byu guys punya alam yang sama',
#  'byu lelet kecil pas hujan padahal sama by telkomsel',
#  'byu kok lo lelet baru hari aku pakai',
#  'aku jadi bimbang mau pakai byu apa hhnnnnnnnnn',
#  'bangsat byu apa sinyal jelek',
#  'sinyal byu kok hilang kemarin admin',
#  'akhir bulan lelet nih apa perlu aku pakai proxy biar cepat byu',
#  'indihome ganggu byu hilang sinyal paksa beli baru paket perdana xl',
#  'sinyal byu aku benar hilang melulu kayak mantan aku dulu haha',
#  'sinyal byu jelek deh',
#  'telkomsel macam tahi kartu halo sama byu aku lelet anjir',
#  'woi bagaimana kenapa janji begini jaring bau telkomsel byu',
#  'sumpah mau pakai byu super lelet kesal bikin mood hancur masih lebih bagus sinyal 3 malah',
#  'kalian tau sih aku tadi juang dulu masa tiba jaring ku bisa terus mau ganti byu lagi baik',
#  'sinyal telkomsel sama byu sih hilang melulu kemarin baru beli kuota malah pakai',
#  'byu aku dosa apa sama lo',
#  'deh byu sinyal jelek melulu sini',
#  'mau buka aplikasi byu lelet',
#  'aku kartu byu 10gb 10 hari terus beli nyata cuma sekali',
#  'byu anjir kok jelek sinyal',
#  'byu aku begini terus allah pengin cek kuota',
#  'telkomsel byu sinyal jelek mati lampu',
#  'pakai byu padahal sama sinyal bletot haha',
#  'byu kenapa sinyal bagus lelet enggak koneksi internetnya padahal kuota ada',
#  'nomor byu kok bisa pakai bikin akun',
#  'anjing byu memang jelek jaring apa jeki lagi down',
#  'aku pakai byu sama telkomsel ya daerah aku pelosok tetap enggak cepat',
#  'ya byu aku baru kemarin promosi orang biar pakai kamu unlimited fup eh malah lelet pas hujan',
#  'byu mati lampu sinyal jelek',
#  'byu memang lelet atau cuma aku',
#  'sinyal byu stabil semua apa daerah aku woi telkomsel benar itu',
#  'sinyal byu h enggak konek konek dua hari woi kuota aku banyak 20gb pas banding sama',
#  'halo byu sinyal lelet kayak kukang dong',
#  'byu bagaimana mau beli kuota aplikasi nya crash terus',
#  'sinyal byu jelek asu',
#  'admin aku mau beli paket bisa terus pagi byu',
#  'halo byu sinyal h melulu kemarin',
#  'byu sinyal lo kok sering hilang mana cepat dulu',
#  'sih byu suka ada sinyal internetnya',
#  'byu kemarin pas jam gin sinyal nya jelek deh anjing',
#  'benar sinyal h byu',
#  'sanggup aku pakai byu sinyal ajak antem melulu allah',
#  'byu tumben jaring nya lelet',
#  'tumben byu kasih hujan sinyal jelek biasa enggak',
#  'byu hujan lelet ya',
#  'kenapa xl byu lelet semua',
#  'biasa ye bangsat sinyal lo aku mau streaming kayak kamu tau byu telkomsel',
#  'yang pakai byu enggak punya kok dapat kuota',
#  'sinyal byu pas mati lampu jelek ya allah mau menang',
#  'apa paket 1mbps 2mbps sebab cepat internet byu jadi lelet sering sinyal cuma 1 bar',
#  'byu ya beli kuota pagi sinyal 4g enggak pakai sama sekali internetnya',
#  'deh byu jaring nya hilang melulu',
#  'siapa mau aku pakai byu soal haha',
#  'kok lemah kali sinyal byu',
#  'kenapa sinyal data sering hilang enggak stabil byu',
#  'byu eror apa bagaimana enggak buat beli paket',
#  'nyata masalah di aku doang enggak beli paket aplikasi eror byu admin benar elah mana cu',
#  'aku baru coba sinyal byu kok h melulu sebentar',
#  'mau beli data begini melulu set padahal aku ada pulsa loh byu',
#  'malam sinyal hilang sekarang cuma jaring 3g kenapa byu',
#  'byu sih sinyal h melulu anjir mau cek kuota enggak',
#  'byu lelet anjir aku mau tonton',
#  'byu eror mau beli kuota kok bisa',
#  'byu ganggu di aku doang',
#  'byu hilang sinyal padahal mau tonton netflix',
#  'byu tiba sinyal hilang pas tonton nadin padahal beli paket unlimited 2mbps',
#  'byu sih jelek sinyal',
#  'byu sih jelek sinyal',
#  'astaga sinyal telkomsel byu sama enggak sinyal',
#  'byu sih lelet begini aku bisa lihat foto mending tidur deh',
#  'admin byu sombong anjing aku mau lapor telkomsel',
#  'byu kenapa sudah lah sinyal lelet aplikasi',
#  'byu tadi sih kok sinyal h terus',
#  'admin byu dong eror jangan lama tadi mau beli kuota begini terus emosi',
#  'lelet dc melulu byu',
#  'apa pas margonda sinyal byu hilang',
#  'byu down apa aku doang',
#  'byu kok tumben ada sinyal',
#  'byu aku hilang sinyal pas konser nadin',
#  'yang byu nya tiba hilang sinyal',
#  'byu kenapa anjir lelet',
#  'kayak iya masa iya byu telkomsel jaring hilang padahal unlimited',
#  'yang pakai telkomsel byu yang jaring ada sama sekali',
#  'apa byu ada sinyal',
#  'byu sama telkomsel deh lelet',
#  'apa sinyal hilang tengah jam byu',
#  'sekarang lelet sih ganggu byu',
#  'byu kok sinyal aku h huhu',
#  'byu jelek sinyal lo biasa begini',
#  'pakai simpati byu sama sekali hilang sinyal',
#  'aku pakai byu ada sinyal pakai 3 lelet',
#  'sinyal byu aku hilang',
#  'byu deh sinyal tiba h',
#  'nih telkomsel byu jadi hilang begini',
#  'sinyal byu kok ampas',
#  'byu tb tb sinyal hilang huft',
#  'punya eror apa memang jaring byu hilang',
#  'woi hilang jaring nya byu',
#  'kok silang sinyal nya byu',
#  'oi pakai byu sinyal hilang',
#  'jaring telkomsel ada sinyal telkomsel byu',
#  'byu aku baru sinyal h tadi hilang',
#  'byu sama telkomsel kenapa',
#  'byu kenapa kok ada sinyal',
#  'sinyal hilang byu mana',
#  'banget mah telkomsel byu sinyal mana kok ada layan',
#  'wah telkomsel ini sinyal provider byu aku jadi nya bangkai',
#  'lah by sinyal mana byu',
#  'pakai telkomsel byu sinyal',
#  'yang pakai byu sinyal hilang',
#  'cok byu sama telkomsel hilang sinyal',
#  'sinyal hilang admin byu ada kali 20 menit',
#  'byu sinyal hilang mewtwo',
#  'kenapa sinyal byu hilang kayak kamu',
#  'pakai byu sinyal sih kok aku silang bangsat',
#  'telkomsel sama byu error apa sinyal aku hilang 22 nya',
#  'sinyal byu hilang hilang ya',
#  'sinyal byu hilang hilang anjing',
#  'ih byu aku ada sinyal tumben',
#  'sinyal tiba ada byu',
#  'begini telkomsel kali byu',
#  'pakai byu sinyal internetnya hilang',
#  'eh byu sinyal nya mana anjing kok hilang kayak doi',
#  'byu hilang sinyal tahi',
#  'byu kenapa kok lelet',
#  'byu sih anjir tiba ada sinyal kuota aku mau habis malam hadeh',
#  'eh telkomsel byu sinyal mu hilang woy ada sama sekali',
#  'juga byu ada jaring sama sekali',
#  'aku pakai byu',
#  'yang ganggu telkomsel apa byu doang',
#  'byu deh tiba ada jaring',
#  'byu kenapa enggak sinyal',
#  'admin sinyal hilang byu banyak lelet',
#  'byu aku kok ada jaring',
#  'sinyal byu sih ah',
#  'byu astagfirullah tiba ada sinyal aku kuliah',
#  'mau tanya pakai byu lelet sih',
#  'byu deh sinyal h melulu',
#  'sinyal byu xl sama telkomsel jelek semua heran',
#  'tadi ya kok begini terus wah sinyal byu bagus',
#  'aku pengin beli paket nya byu youtube lelet asu kemarin',
#  'kenapa padahal pakai jaring byu tetap gan',
#  'byu masalah apa sama aku',
#  'byu sih anjir emosi aku',
#  'allah sinyal byu kesal enggak pakai internetan sama sekali',
#  'byu hilang sinyal',
#  'byu hilang sinyal',
#  'byu hilang sinyal',
#  'telkomsel sama byu apa o kok tiba ada sinyal seluruh wifi indihome nya sekali bisa',
#  'jaring byu jelek deh',
#  'byu sinyal aco deh rumah aku sekarang',
#  'byu anjing sinyal mu busuk',
#  'sinyal byu jelek deh sekarang',
#  'halo yang pakai byu jaring sore ada apa cuma aku',
#  'kartu byu sinyal sekarang kok jelek asu',
#  'ampun byu lelet',
#  'telkomsel byu akhir jaring jelek',
#  'byu memang hujan ganggu kok 11 12 sama tri',
#  'main game pakai by kok reconnect melulu ada apa byu',
#  'lama lama kok aku sebal sama byu',
#  'jaring byu aku ya',
#  'tiap hujan sinyal byu jelek deh',
#  'p p p byu sinyal jelek baik',
#  'byu tambah lelet',
#  'kok aku jaring byu jelek ya',
#  'jadi kesal pakai byu alias makin hari makin lelet',
#  'byu hari sinyal jelek deh',
#  'aplikasi byu error apa aku doang',
#  'byu apa',
#  'lama kartu byu aku']

# %%
keywords(tekspositif).split('\n')
# Out:
# ['byu',
#  'byus',
#  'sama telkomsel',
#  'hari',
#  'apa',
#  'yang',
#  'nya',
#  'kuota gratis kak nindy terimakasih',
#  'dong',
#  'tau',
#  'habis ini bisa pakai haha halo',
#  'enggak ada',
#  'ubah punya aku dari',
#  'bulan',
#  'promo',
#  'kamu bikin paket',
#  'terus',
#  'hilang sinyal beli',
#  'sih',
#  'coba',
#  'ribu isi',
#  'semua mau pesan sim kartu',
#  'mbps suka jadi paling',
#  'sayang',
#  'kayak',
#  'untung kemarin',
#  'mana',
#  'baik',
#  'wow akhir',
#  'sudah',
#  'sekarang',
#  'banyak',
#  'lumayan',
#  'tanya pulsa',
#  'cuma',
#  'mantap',
#  'iny',
#  'unlimited',
#  'rumah',
#  'anak',
#  'kapan baru',
#  'enak',
#  'murah',
#  'pas',
#  'pagi admin',
#  'pengin',
#  'salah memang pilih provider',
#  'anjir',
#  'benar guys kalian',
#  'sini',
#  'bagaimana cara',
#  'jaring',
#  'lama',
#  'cinta',
#  'nyata wifi',
#  'nomor ponsel',
#  'cepat sekali kirim',
#  'kalau',
#  'bukan',
#  'lebih kencang',
#  'aplikasi',
#  'ganti',
#  'kita',
#  'lagi',
#  'kok',
#  'tahun lalu sering tiba',
#  'tadi',
#  'tunggu',
#  'moga tak',
#  'bagus',
#  'harga topping',
#  'cek',
#  'internet',
#  'youtube',
#  'stream',
#  'deh',
#  'begini',
#  'dulu biar',
#  'siapa',
#  'pale',
#  'kali',
#  'yuk',
#  'makin aman',
#  'terima kasih tidak',
#  'lelet',
#  'padahal cocok buat ajar',
#  'besok',
#  'lancar',
#  'gila',
#  'anniversary',
#  'oke',
#  'dapat',
#  'aktif',
#  'malah asih',
#  'senang',
#  'tetap',
#  'lihat',
#  'soal',
#  'lewat',
#  'bakal',
#  'kan tani',
#  'indosat',
#  'doang',
#  'pernah',
#  'nih',
#  'masuk',
#  'erti butuh',
#  'data',
#  'bonus',
#  'ikut',
#  'tonton bareng',
#  'bawa asa',
#  'tanggal',
#  'teman',
#  'orang',
#  'tapi',
#  'internetan',
#  'tri',
#  'jam',
#  'sampai',
#  'tambah',
#  'depan streaming',
#  'ira',
#  'pokok malam minggu',
#  'sesal lah',
#  'alhamdulillah',
#  'biasa',
#  'happy',
#  'khusus',
#  'masa',
#  'keluar',
#  'selamat',
#  'asyik',
#  'jangan',
#  'berapa',
#  'gara',
#  'kerja',
#  'kata',
#  'kemendikbud',
#  'minta',
#  'anjing',
#  'bayar',
#  'lupa melulu',
#  'loh',
#  'woy menang',
#  'saja',
#  'itu',
#  'satu',
#  'langsung',
#  'ingat',
#  'bingung',
#  'hidup',
#  'iya',
#  'panjang',
#  'simpati',
#  'hehe',
#  'hadiah tiap',
#  'diskon',
#  'sempat',
#  'nikmat',
#  'hemat duit',
#  'akun',
#  'hihi',
#  'cari',
#  'hasil',
#  'datang waktu',
#  'mah',
#  'bantu',
#  'twitter',
#  'baca',
#  'lain',
#  'buka',
#  'hai',
#  'tengah',
#  'tarik',
#  'rasa',
#  'pertama',
#  'maaf masih',
#  'siap',
#  'jalan',
#  'stabil',
#  'kaget',
#  'zoom',
#  'akses',
#  'mati',
#  'iklan',
#  'huhu',
#  'pindah',
#  'ambil indomart',
#  'gin',
#  'lanjut',
#  'monthiversary',
#  'niat',
#  'notifikasi',
#  'mending',
#  'wah',
#  'unduh',
#  'balik',
#  'iseng',
#  'perlu',
#  'daftar',
#  'dengar',
#  'langgeng',
#  'nama',
#  'digital',
#  'digit',
#  'hujan',
#  'allah',
#  'saya kurang',
#  'penasaran seru',
#  'selalu',
#  'boros',
#  'cie',
#  'alias sabar',
#  'kakak',
#  'goda',
#  'doi',
#  'layan',
#  'ampun',
#  'takut',
#  'betah',
#  'ayo',
#  'sedikit',
#  'woi',
#  'setia',
#  'mulai',
#  'maksud',
#  'layak',
#  'racun',
#  'indihome',
#  'dan',
#  'btw',
#  'pekan',
#  'yey',
#  'ulas',
#  'usah',
#  'maksimal',
#  'menit',
#  'beda bagi',
#  'video',
#  'btstwt',
#  'promonya',
#  'tokopedia',
#  'luar',
#  'ketemu',
#  'operator',
#  'harus',
#  'haru',
#  'segera',
#  'promosi',
#  'jual',
#  'suruh',
#  'batas',
#  'juga',
#  'tgg end']

# %%
keywords(teksnegatif).split('\n')
# Out:
# ['aku',
#  'telkomsel hilang sinyal anak nih byu',
#  'enggak',
#  'kok kuota',
#  'apa',
#  'sama youtube bisa pakai padahal banyak',
#  'ada',
#  'jadi',
#  'kemarin lelet benar',
#  'terus',
#  'anjing',
#  'beli',
#  'sial nya sih',
#  'kartu baru',
#  'begini melulu sim',
#  'jelek tumben',
#  'cuma',
#  'memang',
#  'deh',
#  'lama',
#  'lah',
#  'aneh admin',
#  'tadi pas buka',
#  'gila jaring naik',
#  'cepat',
#  'bikin',
#  'hari lalu',
#  'mau isi pulsa belum',
#  'anjir',
#  'woi',
#  'sebal kenapa',
#  'sekarang',
#  'tonton',
#  'paket data',
#  'lagi',
#  'sekali',
#  'buruk kayak indihome',
#  'hujan',
#  'ganggu',
#  'jangan',
#  'sudah',
#  'halo',
#  'doang',
#  'nyata',
#  'buat main',
#  'kesal',
#  'sumpah',
#  'ini',
#  'kalis',
#  'masa',
#  'turun saya bagaimana dong',
#  'coba',
#  'tiba',
#  'koneksi',
#  'jam gin',
#  'parah',
#  'masuk',
#  'haha',
#  'rumah',
#  'error',
#  'malah lag',
#  'bangsat woy',
#  'ganti provider kamu macet',
#  'masalah',
#  'nomor',
#  'langsung',
#  'akhir',
#  'habis',
#  'bagus makin sini',
#  'stabil',
#  'baik',
#  'update aplikasi',
#  'malam gmeet',
#  'dulu',
#  'ribu',
#  'balas',
#  'sering',
#  'yang punya',
#  'susah',
#  'lancar',
#  'tiap',
#  'kali awal',
#  'daerah mana',
#  'pagi',
#  'lebih',
#  'semua',
#  'unlimited',
#  'kirim',
#  'allah',
#  'sampai',
#  'dua internet',
#  'mbps',
#  'live streaming',
#  'topping',
#  'unduh',
#  'kalau mati listrik',
#  'whatsapp',
#  'kalian',
#  'kata',
#  'stream vlive',
#  'jelas tahi',
#  'bayar',
#  'tidak',
#  'wifi',
#  'bulan aktif',
#  'tau',
#  'suka',
#  'gilir',
#  'video',
#  'dapat',
#  'minggu',
#  'biasa',
#  'tri',
#  'twitter',
#  'untung',
#  'nindy',
#  'rasa ping menang',
#  'guna game ponsel kadang',
#  'biar',
#  'eror',
#  'gara',
#  'cek',
#  'sesal',
#  'internetnya',
#  'emosi',
#  'kan',
#  'selalu',
#  'loh',
#  'ikut',
#  'pengin kelah',
#  'customer',
#  'custom',
#  'hiks',
#  'online',
#  'promo',
#  'busuk',
#  'lihat',
#  'lewat',
#  'minta ampun',
#  'dari',
#  'tengah',
#  'kak',
#  'gagal',
#  'tetap',
#  'besok',
#  'mala',
#  'malas',
#  'pernah',
#  'mulai',
#  'maaf',
#  'tapi',
#  'keluar',
#  'sms',
#  'tambah masih',
#  'pingnya asu',
#  'tanya',
#  'beberapa orang keluh',
#  'mahal',
#  'soal',
#  'mohon',
#  'kurang',
#  'kerja tugas',
#  'sendiri',
#  'menit',
#  'aduh',
#  'bantu',
#  'ambil',
#  'hancur',
#  'saja',
#  'sedih',
#  'asli',
#  'satu',
#  'kecewa',
#  'ajak',
#  'ampas',
#  'tinggal',
#  'buffering',
#  'buffer',
#  'banget penting terimakasih',
#  'bakal',
#  'beda',
#  'kapan',
#  'balik',
#  'waduh',
#  'sedot',
#  'siang jawab',
#  'aktivasi login',
#  'tidur',
#  'itu',
#  'sayang',
#  'lampu',
#  'layan komplain',
#  'ngegame',
#  'kakak',
#  'indosat',
#  'internetan',
#  'aman capek',
#  'akun',
#  'mantap',
#  'kualitas',
#  'chat',
#  'axis',
#  'bingung',
#  'dear',
#  'mah',
#  'viu',
#  'muncul',
#  'enak',
#  'astaga mending',
#  'tunda',
#  'sabar tunggu',
#  'salah',
#  'bukan',
#  'nyala',
#  'belakang alias',
#  'putar',
#  'bilang',
#  'kasih',
#  'kendala',
#  'kuat',
#  'boros',
#  'boro',
#  'sebentar',
#  'daftar',
#  'amp',
#  'kota',
#  'telpon',
#  'asa',
#  'lambat',
#  'marah',
#  'tolong',
#  'paling',
#  'siapa',
#  'cok',
#  'sedikit',
#  'ajar',
#  'dana',
#  'ulang',
#  'harus',
#  'haru',
#  'lapor',
#  'kelar',
#  'kec negeri',
#  'fuck',
#  'ayo',
#  'hai',
#  'servis',
#  'jalan',
#  'wah',
#  'sedang',
#  'loading',
#  'akses',
#  'cara',
#  'indomart ira',
#  'bogor',
#  'rumit',
#  'terima',
#  'saldo',
#  'gembel',
#  'merah',
#  'usah',
#  'zoom',
#  'asyik',
#  'tahun',
#  'beres',
#  'kbps',
#  'datang']

# %%
def get_word_frequency(tweets, count_once_per_tweet=False):
   
    count_all = Counter()
    for tweet in tweets:
        tokens = word_tokenize(tweet)
        terms_all = [term for term in tokens]
        if count_once_per_tweet:
            terms_all = set(terms_all) 
        count_all.update(terms_all) # update the counter
    return count_all

# %%
pos_tweet = get_word_frequency(positif['text'].values)
neg_tweet = get_word_frequency(negatif['text'].values)

# %%
pos_tweet
# Out:
# Counter({'siang': 5,
#          'kuota': 373,
#          'gratis': 52,
#          'kak': 18,
#          'nindy': 72,
#          'terimakasih': 162,
#          'byu': 1562,
#          'aneh': 6,
#          'ku': 38,
#          'habis': 100,
#          'ini': 36,
#          'bisa': 53,
#          'pakai': 337,
#          'haha': 84,
#          'halo': 27,
#          'cek': 52,
#          'dm': 51,
#          'salah': 11,
#          'memang': 36,
#          'pilih': 24,
#          'provider': 145,
#          'hampir': 5,
#          'tahun': 47,
#          'lalu': 19,
#          'sering': 30,
#          'tiba': 35,
#          'wow': 86,
#          'akhir': 135,
#          'internet': 179,
#          'bebas': 78,
#          'kamu': 153,
#          'bikin': 111,
#          'paket': 223,
#          'semua': 93,
#          'mau': 234,
#          'pesan': 79,
#          'sim': 109,
#          'kartu': 188,
#          'selamat': 19,
#          '6': 10,
#          'monthiversary': 17,
#          'sayang': 59,
#          'dong': 79,
#          'tahan': 4,
#          'ya': 45,
#          'gila': 23,
#          'good': 1,
#          'deals': 1,
#          'tanya': 39,
#          'pulsa': 78,
#          'sama': 155,
#          'telkomsel': 107,
#          'sih': 65,
#          'di': 38,
#          'ubah': 11,
#          'punya': 34,
#          'aku': 287,
#          'dari': 12,
#          'utuh': 1,
#          'lupa': 9,
#          'melulu': 12,
#          'tiup': 1,
#          'gtlt': 2,
#          'moga': 47,
#          'tak': 8,
#          'kecewa': 3,
#          'benar': 32,
#          'guys': 41,
#          'kalian': 19,
#          'makin': 41,
#          'aman': 13,
#          'jaya': 7,
#          '2': 25,
#          'mbps': 20,
#          'suka': 28,
#          'jadi': 110,
#          'paling': 32,
#          'andal': 2,
#          'tethering': 3,
#          'bajing': 3,
#          'telkom': 1,
#          'lelet': 19,
#          'nyata': 36,
#          'wifi': 20,
#          'error': 4,
#          'untung': 78,
#          'kemarin': 48,
#          'sambung': 1,
#          'hidup': 10,
#          'hilang': 27,
#          'sinyal': 52,
#          'beli': 178,
#          'akun': 12,
#          'adik': 3,
#          'btw': 7,
#          'enggak': 75,
#          'ada': 71,
#          'saat': 6,
#          'mati': 8,
#          'lampu': 3,
#          'selalu': 9,
#          'krusial': 1,
#          'indosat': 21,
#          'keren': 7,
#          'terus': 54,
#          'mbak': 2,
#          'datang': 7,
#          'waktu': 14,
#          'tepat': 3,
#          'bilang': 5,
#          'traktir': 3,
#          'aaaa': 3,
#          'senang': 17,
#          'sampai': 11,
#          'lebih': 40,
#          'kencang': 13,
#          'unggah': 5,
#          'unduh': 8,
#          'sangar': 1,
#          'erti': 13,
#          'butuh': 21,
#          'harga': 17,
#          'topping': 36,
#          'permanen': 3,
#          'pagi': 19,
#          'admin': 86,
#          'mumpung': 4,
#          'libur': 7,
#          'yuk': 18,
#          'ira': 17,
#          'trending': 10,
#          'yang': 116,
#          'tren': 3,
#          'bukan': 20,
#          'combo': 1,
#          'sakti': 1,
#          'belakang': 4,
#          'move': 7,
#          'on': 11,
#          'keluarga': 2,
#          'kena': 1,
#          'racun': 7,
#          'minta': 12,
#          'trendi': 1,
#          'nya': 82,
#          'masterchefina': 2,
#          'coba': 70,
#          'unlimited': 66,
#          '1': 33,
#          'rasa': 9,
#          'em': 1,
#          'mantap': 46,
#          'iseng': 8,
#          'kali': 21,
#          'murah': 44,
#          'beberapa': 4,
#          'hari': 129,
#          'perdana': 4,
#          'shopeeid': 1,
#          'tadi': 25,
#          'cepat': 45,
#          'sekali': 22,
#          'kirim': 16,
#          '5': 9,
#          'ribu': 164,
#          'isi': 37,
#          '1gb': 11,
#          'teman': 19,
#          'malah': 18,
#          'asih': 25,
#          '50': 39,
#          'baca': 7,
#          'thread': 1,
#          'kata': 10,
#          'pengin': 41,
#          'tau': 83,
#          'samarinda': 2,
#          'jaring': 39,
#          'promo': 109,
#          '15mb': 1,
#          '2mb': 3,
#          'kapan': 11,
#          'baru': 67,
#          'ejector': 1,
#          'lumayan': 37,
#          'terima': 34,
#          'kasih': 66,
#          'tidak': 6,
#          'lag': 3,
#          'hujan': 5,
#          'badai': 1,
#          'pokok': 8,
#          'malam': 25,
#          'minggu': 10,
#          'rumah': 31,
#          'mama': 4,
#          'mertua': 1,
#          'cuaca': 1,
#          'besar': 2,
#          'lokasi': 2,
#          'cihampelas': 1,
#          'bandung': 2,
#          'tunggu': 24,
#          'serasa': 5,
#          'jodoh': 2,
#          'alias': 7,
#          'sabar': 6,
#          'ketemu': 5,
#          'info': 2,
#          'mana': 37,
#          'makassar': 1,
#          'supirpete2': 1,
#          'harap': 5,
#          'khusus': 15,
#          'quora': 1,
#          'showroom': 1,
#          'minat': 2,
#          'sedikit': 5,
#          'hanya': 3,
#          'kelompok': 1,
#          'orang': 12,
#          'sekarang': 48,
#          'liveon': 3,
#          'xlaxiatatbk': 2,
#          'tebing': 1,
#          'tinggi': 1,
#          'sumut': 1,
#          'tetiba': 1,
#          'sms': 6,
#          'sudah': 45,
#          'langgeng': 13,
#          'happy': 22,
#          '1st': 2,
#          'anniversary': 30,
#          'maksud': 8,
#          'apa': 90,
#          'mohon': 8,
#          'maaf': 6,
#          'masih': 10,
#          'mula': 1,
#          'kayak': 39,
#          'bonus': 18,
#          'begini': 21,
#          'eveyhvmmond': 1,
#          'gemas': 4,
#          'surat': 1,
#          'kaget': 10,
#          'notifikasi': 10,
#          '2gb': 12,
#          'banyak': 53,
#          'lama': 30,
#          'bawa': 6,
#          'asa': 29,
#          'adminnya': 1,
#          'ready': 1,
#          'kan': 26,
#          'tani': 6,
#          'begadang': 1,
#          'ambil': 8,
#          'indomart': 9,
#          'indomilk': 1,
#          '9': 17,
#          'anjir': 30,
#          'post': 1,
#          'deh': 20,
#          'saja': 14,
#          'siapa': 28,
#          'kok': 28,
#          '100': 80,
#          'padahal': 29,
#          'cocok': 6,
#          'buat': 30,
#          'ajar': 21,
#          'eh': 23,
#          '3': 29,
#          'baik': 45,
#          'ganti': 46,
#          'nih': 18,
#          '10gb': 22,
#          '20': 6,
#          'per': 5,
#          'aplikasi': 31,
#          'ngejos': 1,
#          'sisa': 6,
#          'ba': 2,
#          'tonton': 21,
#          'bareng': 8,
#          'virtual': 1,
#          'konser': 1,
#          'online': 4,
#          'here': 1,
#          'comes': 1,
#          'the': 7,
#          'sun': 1,
#          'goplayindonesia': 1,
#          'enak': 43,
#          'nomor': 41,
#          'ponsel': 18,
#          'perlu': 8,
#          'pusing': 1,
#          'hasil': 8,
#          'undi': 1,
#          'tipu': 4,
#          'pinjam': 2,
#          'abal-abal': 1,
#          '11gb': 2,
#          'sana': 4,
#          'tumpah': 1,
#          'beda': 5,
#          'bagi': 11,
#          'normal': 2,
#          'pacar': 6,
#          'raya': 2,
#          'cinta': 49,
#          'royal': 1,
#          'tokopedia': 6,
#          'tokopediacare': 1,
#          'lewat': 18,
#          'hai': 12,
#          'aktif': 25,
#          'sedang': 5,
#          'jalan': 8,
#          'ajak': 3,
#          'hihi': 11,
#          'lagi': 22,
#          'internetan': 16,
#          'alhamdulillah': 13,
#          'nama': 6,
#          'turut': 3,
#          'layak': 8,
#          'hemat': 10,
#          'duit': 9,
#          'awal': 6,
#          '5gb': 7,
#          '65': 1,
#          'kkm': 1,
#          '140': 6,
#          'dulu': 20,
#          'biar': 19,
#          'hubung': 3,
#          'nyaman': 5,
#          'tenang': 4,
#          'se': 2,
#          'asyik': 17,
#          'kado': 5,
#          'bagaimana': 42,
#          'cara': 25,
#          'rp': 5,
#          '90': 2,
#          '0': 4,
#          'gatal': 1,
#          'lihat': 19,
#          'nge': 4,
#          'juga': 10,
#          'loh': 20,
#          'pekan': 13,
#          'wah': 10,
#          '15': 10,
#          'gb': 34,
#          'asal': 2,
#          'cuma': 59,
#          '10': 31,
#          'utama': 10,
#          'whatsappan': 1,
#          'kita': 26,
#          'bandel': 1,
#          'bunda': 2,
#          'besok': 20,
#          'miracle': 1,
#          '50gb': 75,
#          '15mbps': 3,
#          '2mbps': 23,
#          'woy': 4,
#          'menang': 15,
#          'mifi': 1,
#          'ah': 15,
#          'sadar': 5,
#          'diri': 3,
#          'pernah': 22,
#          'oke': 18,
#          'voucher': 8,
#          'pas': 37,
#          'mewah': 1,
#          'tunjuk': 2,
#          'tangan': 2,
#          'bulan': 95,
#          'pol': 1,
#          'polan': 1,
#          'anak': 73,
#          'hehe': 13,
#          'lanjut': 8,
#          'cuk': 1,
#          'ayo': 9,
#          'saing': 2,
#          'siap': 8,
#          'perang': 1,
#          'itu': 10,
#          'yuhu': 2,
#          'dan': 7,
#          '7gb': 1,
#          'daripada': 2,
#          'kasihan': 3,
#          'suami': 1,
#          'pasang': 6,
#          '23gb': 4,
#          '23': 3,
#          'uwu': 3,
#          'terlalu': 4,
#          'pertama': 13,
#          'doang': 18,
#          'sesal': 12,
#          'lah': 17,
#          'rekomendasi': 4,
#          'series': 1,
#          'bagus': 38,
#          'drama': 6,
#          'korea': 5,
#          'boleh': 2,
#          'seb': 1,
#          'kalau': 24,
#          'mah': 9,
#          'ooredoo': 2,
#          'lancar': 21,
#          'tethring': 2,
#          'istri': 2,
#          'huhu': 8,
#          '30': 14,
#          'mulai': 5,
#          'maret': 1,
#          'hingga': 1,
#          'rewand': 1,
#          'sahabat': 6,
#          'nikmat': 13,
#          'rupa': 1,
#          'satu': 13,
#          'putus': 2,
#          'dalam': 1,
#          'operator': 8,
#          'kuat': 4,
#          'dapat': 22,
#          'imut': 1,
#          'kosong': 2,
#          'hookspaceid': 1,
#          'order': 6,
#          'lucu': 4,
#          'tinggal': 5,
#          'antar': 4,
#          'entar': 3,
#          'ulas': 11,
#          'takut': 6,
#          'sore': 4,
#          'doi': 7,
#          'langsung': 12,
#          'a': 7,
#          'obat': 3,
#          'tuh': 2,
#          'masa': 18,
#          'bodoh': 4,
#          'ikut': 15,
#          'turun': 2,
#          'penting': 5,
#          'data': 36,
#          'depan': 9,
#          'streaming': 17,
#          'channel': 1,
#          'gayengco': 1,
#          'b': 3,
#          'nah': 2,
#          '15gb': 15,
#          'bungkus': 1,
#          'dua': 4,
#          'genks': 1,
#          'hashtag': 2,
#          'pikir': 6,
#          'rekor': 2,
#          '30gb': 3,
#          'bakal': 13,
#          '100gb': 7,
#          'suruh': 5,
#          'down': 5,
#          'promonya': 9,
#          'tahi': 2,
#          'main': 5,
#          'lol': 2,
#          'genshin': 1,
#          'impact': 1,
#          'kek': 1,
#          'mahal': 5,
#          'gaji': 2,
#          'cc': 3,
#          'dilema': 1,
#          'by': 103,
#          'gede': 1,
#          'card': 9,
#          'webinar': 3,
#          'simnya': 1,
#          'sekitar': 1,
#          'vi': 1,
#          'cari': 9,
#          'long': 9,
#          'ngekost': 1,
#          'melarat': 1,
#          'sumpah': 8,
#          'semenjak': 5,
#          'gara': 1,
#          'mur': 1,
#          'ngadi': 4,
#          'liur': 1,
#          'sebentar': 3,
#          'abang': 1,
#          'kakak': 7,
#          'ipar': 1,
#          'recommended': 2,
#          'tara': 2,
#          'penasaran': 10,
#          'seru': 6,
#          'segera': 7,
#          'tanggal': 15,
#          '28': 3,
#          'dia': 1,
#          'hadiah': 13,
#          'tiap': 25,
#          'masalah': 5,
#          'otak': 1,
#          'full': 2,
#          'referral': 4,
#          'ambassador': 1,
#          'biasa': 15,
#          'banget': 3,
#          'keburu': 3,
#          'lamun': 1,
#          'bahagia': 4,
#          'pindah': 12,
#          'twitteran': 2,
#          'ter': 2,
#          'jam': 19,
#          'zaman': 1,
#          'layan': 5,
#          'ramah': 4,
#          'dek': 1,
#          'allah': 9,
#          'sini': 34,
#          'tambah': 18,
#          'klik': 5,
#          'ucap': 5,
#          'masuk': 14,
#          'ke': 11,
#          'parah': 3,
#          'limpah': 3,
#          'tri': 16,
#          '55gb': 1,
#          'barbar': 1,
#          'miskin': 3,
#          'tt': 1,
#          'kini': 1,
#          'mudah': 3,
#          'bayar': 11,
#          'panjang': 8,
#          'wajib': 1,
#          'borong': 1,
#          'puas': 6,
#          'jawab': 3,
#          'soal': 14,
#          'pekanbaru': 2,
#          'tengkulak': 1,
#          'beri': 3,
#          'tapi': 15,
#          'xl': 25,
#          'daftar': 10,
#          'oh': 1,
#          'iya': 11,
#          'cerita': 4,
#          'kenal': 6,
#          'ganteng': 2,
#          'buru': 3,
#          'akibat': 1,
#          'dampar': 1,
#          'telpon': 5,
#          'relasi': 1,
#          'nyemplung': 1,
#          'ppppp': 2,
#          'bingung': 15,
#          '32gb': 2,
#          '80': 1,
#          'konek': 1,
#          'otomatis': 4,
#          'bentar': 4,
#          'niat': 8,
#          'pada': 6,
#          'tumpang': 1,
#          'esim': 3,
#          'hiks': 2,
#          'kumpul': 2,
#          'waduh': 2,
#          'akan': 2,
#          'goda': 7,
#          'tarik': 11,
#          'mu': 4,
#          'unlimitednya': 3,
#          '75': 2,
#          '130gb': 1,
#          'pale': 1,
#          '12gb': 2,
#          'ueue': 1,
#          'bang': 3,
#          'nin': 6,
#          'kumat': 2,
#          'hangus': 2,
#          'kau': 4,
#          'fikir': 1,
#          'betah': 10,
#          'tell': 1,
#          'me': 3,
#          'segala': 3,
#          'promosi': 6,
#          'kejut': 3,
#          'serius': 3,
#          'as': 3,
#          '117gb': 2,
#          'gengs': 2,
#          'gapai': 1,
#          'kemendikbud': 14,
#          'jancuk': 1,
#          'keluar': 10,
#          'dada': 2,
#          'kecep': 1,
#          'kemendikbudri': 3,
#          'jujur': 3,
#          'saya': 6,
#          'kurang': 7,
#          'giur': 2,
#          'kenyang': 3,
#          'hue': 1,
#          'connect': 1,
#          'jangan': 11,
#          'laku': 3,
#          'berapa': 13,
#          'khilaf': 1,
#          'gitu': 1,
#          'tua': 3,
#          'spesial': 3,
#          'smartfrenworld': 1,
#          'rubah': 2,
#          'konsep': 1,
#          'midnight': 1,
#          'gusur': 1,
#          'pelit': 3,
#          'i': 1,
#          'love': 1,
#          'you': 1,
#          'kantong': 4,
#          'teh': 3,
#          'film': 4,
#          'bufferingnya': 1,
#          'diskon': 7,
#          'testimoni': 1,
#          'indihome': 6,
#          'banding': 3,
#          'cie': 10,
#          'tern': 1,
#          'terbang': 1,
#          'bohong': 2,
#          'customer': 5,
#          'service': 5,
#          'keluh': 1,
#          'gin': 8,
#          'hitung': 1,
#          'mending': 8,
#          '25gb': 12,
#          'shopee': 4,
#          'balas': 7,
#          'seminar': 1,
#          'zoom': 11,
#          'gmeet': 1,
#          'bengong': 1,
#          'bismillah': 2,
#          'tuju': 1,
#          'anti': 2,
#          'afk': 1,
#          'club': 1,
#          'lepas': 2,
#          'update': 5,
#          'langgan': 3,
#          'berat': 3,
#          'gagal': 2,
#          'apk': 4,
#          '40': 2,
#          'halal': 1,
#          'tetap': 18,
#          'reward': 5,
#          'aww': 4,
#          'pipipipip': 1,
#          'nan': 1,
#          'canggih': 1,
#          'mas': 9,
#          'sesuai': 3,
#          'sales': 1,
#          'karena': 5,
#          'wfh': 1,
#          'hua': 3,
#          'gaya': 1,
#          'desain': 2,
#          'youtube': 25,
#          'kualitas': 3,
#          '720p': 3,
#          'buffering': 2,
#          'pak': 2,
#          'androbuntu': 1,
#          'hebat': 2,
#          'bar': 3,
#          'akrab': 1,
#          'sendiri': 6,
#          'asli': 5,
#          'cukup': 2,
#          'gaul': 5,
#          'sweet': 3,
#          'sekaligus': 1,
#          'krisis': 2,
#          'telegram': 2,
#          'hotspotin': 1,
#          'laptop': 2,
#          'apn': 2,
#          'aga': 1,
#          'stabil': 8,
#          'kegabutan': 1,
#          'heran': 1,
#          'twitter': 10,
#          'personal': 1,
#          'hotspot': 2,
#          'takdir': 1,
#          'perhati': 5,
#          'rapat': 1,
#          'taruh': 3,
#          'ulang': 4,
#          'gift': 2,
#          'aktivasinya': 1,
#          'milik': 2,
#          'kendala': 1,
#          'ihiiyy': 1,
#          'hh': 1,
#          'pamer': 3,
#          'tipe': 2,
#          'uuuu': 1,
#          'direspon': 1,
#          'smartfren': 7,
#          'euy': 2,
#          'ngekoplo': 1,
#          'koneksi': 5,
#          'wey': 1,
#          'guna': 4,
#          'luar': 4,
#          'gabung': 2,
#          'akses': 8,
#          'super': 1,
#          '34gb': 9,
#          '275': 1,
#          '8': 2,
#          'menit': 4,
#          '203': 1,
#          'streamingnya': 2,
#          'sempat': 9,
#          'prioritas': 2,
#          'iklan': 7,
#          'spotify': 2,
#          'kerja': 9,
#          'tugas': 3,
#          'video': 5,
#          'kompetisi': 1,
#          'ganggu': 1,
#          'ampun': 7,
#          'lho': 2,
#          'barusan': 4,
#          'harus': 5,
#          'pergi': 1,
#          'demi': 1,
#          'yey': 8,
#          'bokek': 1,
#          'adcuma': 1,
#          'walah': 3,
#          'saldo': 2,
#          'gara-gara': 8,
#          'tampung': 1,
#          'cii': 1,
#          'kutip': 1,
#          'laundry': 1,
#          'saran': 4,
#          'agam': 1,
#          'jauh': 4,
#          'exp': 1,
#          'date': 1,
#          'rezeki': 2,
#          'nomplok': 1,
#          'sangka': 4,
#          '12': 2,
#          'purnama': 3,
#          'usah': 7,
#          'khawatir': 2,
#          'paksa': 1,
#          'p': 5,
#          'kode': 3,
#          'positif': 4,
#          'st': 1,
#          'time': 1,
#          '1mbps': 2,
#          '1mb': 1,
#          'tipsnya': 1,
#          'queen': 1,
#          '34': 2,
#          'dukung': 3,
#          'setia': 8,
#          'bcs': 1,
#          '80gb': 1,
#          'will': 1,
#          'sok': 5,
#          'far': 2,
#          'ekonomis': 2,
#          'bel': 1,
#          'rencana': 1,
#          'pasti': 5,
#          'pusat': 1,
#          'kota': 4,
#          'semarang': 1,
#          'istimewa': 1,
#          'tengah': 9,
#          'cilung': 1,
#          'chocopieez': 1,
#          'joyon': 1,
#          'akimoodz': 1,
#          'angkat': 2,
#          'headsetku': 1,
#          'rusak': 3,
#          'redam': 1,
#          'suara': 3,
#          'perangkat': 1,
#          'fokus': 2,
#          'true': 1,
#          'sight': 1,
#          'ti1719': 1,
#          'set': 2,
#          '1080p': 1,
#          'nonaktif': 1,
#          'unchhh': 1,
#          'totwitt': 1,
#          'netflix': 6,
#          'transfer': 6,
#          'opsi': 1,
#          'up': 9,
#          'kartun': 1,
#          'fitur-fitur': 1,
#          'duh': 1,
#          'jarang': 2,
#          'kuis': 1,
#          'nindynya': 2,
#          'u': 1,
#          'mampir': 1,
#          'zona': 1,
#          'cemilan': 1,
#          'artikel': 1,
#          'absen': 2,
#          'semangat': 3,
#          'metode': 1,
#          'menggunakkan': 1,
#          'mbanking': 2,
#          'bni': 1,
#          'misal': 3,
#          'dengan': 3,
#          'henti': 1,
#          'buah': 2,
#          'hormat': 1,
#          'naik': 5,
#          'halah': 1,
#          'oe': 1,
#          'gebetan': 1,
#          'tampak': 1,
#          'like': 3,
#          'under': 1,
#          'tel': 1,
#          'kantor': 1,
#          'buka': 11,
#          'ig': 2,
#          'webtoon': 1,
#          'viu': 3,
#          'n': 1,
#          'sungguh': 2,
#          'jual': 13,
#          'wa': 1,
#          't': 1,
#          'sf': 3,
#          'axis': 4,
#          'bong': 1,
#          'debut': 2,
#          'usaha': 1,
#          'enam': 1,
#          'kecil': 1,
#          'bun': 2,
#          'dengar': 7,
#          'audio': 1,
#          'kala': 2,
#          'bosan': 2,
#          'dikirimin': 5,
#          'total': 2,
#          '110': 3,
#          'pandemi': 1,
#          'covid': 1,
#          'brojol': 1,
#          'pjj': 1,
#          'hoho': 2,
#          'nagih': 1,
#          'aktivasi': 5,
#          'sengaja': 1,
#          'toppingnya': 2,
#          'hm': 10,
#          '2500': 1,
#          'jae': 1,
#          'ngetwitch': 1,
#          'pulang': 1,
#          'anjing': 10,
#          'balik': 8,
#          'emosi': 3,
#          'au': 1,
#          '11': 1,
#          'cu': 2,
#          'dear': 6,
#          'diaktivasi': 1,
#          'urus': 4,
#          'blog': 1,
#          'competition': 1,
#          'jalantikus': 1,
#          'komentar': 1,
#          'curhat': 1,
#          'alam': 3,
#          'aaaaak': 1,
#          'giveaway': 2,
#          '25': 9,
#          '123': 1,
#          'umum': 2,
#          'peme': 1,
#          'simpati': 9,
#          'goceng': 1,
#          'mbankin': 1,
#          'kamar': 1,
#          'omong': 2,
#          'rip': 1,
#          'hey': 2,
#          'haduh': 1,
#          'ads': 1,
#          'extra': 1,
#          'link': 3,
#          'jne': 2,
#          'btstwt': 5,
#          'promoan': 3,
#          'ih': 4,
#          'hshwqushq': 1,
#          'kampung': 2,
#          'lebi': 1,
#          'bro': 2,
#          'para': 3,
#          'finansial': 1,
#          'jnecare': 1,
#          'mwah': 1,
#          'dadah': 1,
#          'web': 1,
#          'ongkir': 1,
#          'pulau': 1,
#          'jawa': 1,
#          'bos': 1,
#          'avv': 1,
#          'bagai': 4,
#          'informasi': 1,
#          'cus': 1,
#          'whatsapp': 6,
#          'pc': 3,
#          'checkout': 1,
#          'unpad': 1,
#          'laaa': 1,
#          '666': 1,
#          'keranjang': 1,
#          'selesai': 3,
#          'lain': 7,
#          'hiksrot': 1,
#          'eleh': 2,
#          'senin': 2,
#          'muram': 1,
#          '5g': 1,
#          'costumer': 1,
#          'care': 1,
#          'sistem': 1,
#          'nanti': 3,
#          'site': 1,
#          'masterchef': 1,
#          'tiktokan': 1,
#          'kenapa': 4,
#          'vlive': 2,
#          'an': 6,
#          'platform': 1,
#          'betul': 5,
#          'cair': 1,
#          'pensiun': 1,
#          'padang': 1,
#          'pes': 1,
#          ...})

# %%
def plot_word_frequency(data, color='k', title='Twitter Word Count'):
    words, counts = zip(*data) 
    val = counts[::-1]   # sort the bars from longest to shortest
    words = words[::-1]
    pos = np.arange(len(data))+.5  # center the bars on the y axis
    
    plt.figure(figsize=(12,12))
    plt.barh(pos, val, align='center', color=color)
    plt.yticks(pos, words)
    plt.xlabel('Count')
    plt.title(title)
    plt.grid(True)
    plt.show()

plot_word_frequency(pos_tweet.most_common(20),'chartreuse','Most Common Words: Positive Tweets')
plot_word_frequency(neg_tweet.most_common(20),'tomato','Most Common Words: negative Tweets')

# %% [markdown]
# visualize sentiment base on device

# %%
positifTest=data.loc[data.label=="positif"]
negatifTest=data.loc[data.label=="negatif"]

# %%
def get_source_label(source):
    jum = Counter(source).most_common()
    sour = []
    for sou, count in jum[:10]:
        sour.append(sou)
    return sour

def get_count_source(source,list_source):
    count_source = []
    list_source = pd.Series(list_source, dtype=object).tolist()
    for so in source:
        count = list_source.count(so)
        count_source.append(count)
     # update the counter
    return count_source

# %%
def show_count_sent(label,var1,var2,title):
    font = {'family' : 'arial',
            'weight' : 'normal',
            'size'   : 18}
    plt.rc('font', **font)

    labels = label
    positif = get_count_source(labels,var1)
    negatif = get_count_source(labels,var2)

    x = np.arange(len(labels))  # the label locations
    width = 0.35  # the width of the bars

    fig = plt.figure(figsize=(20, 10))
    ax = fig.subplots()
    rects1 = ax.bar(x - width/2, positif, width, label='Positive')
    rects2 = ax.bar(x + width/2, negatif, width, label='Negative')

    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel('Count')
    ax.set_title(title)
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.legend()

    def autolabel(rects):
        """Attach a text label above each bar in *rects*, displaying its height."""
        for rect in rects:
            height = rect.get_height()
            ax.annotate('{}'.format(height),
                        xy=(rect.get_x() + rect.get_width() / 2, height),
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points",
                        ha='center', va='bottom')


    autolabel(rects1)
    autolabel(rects2)

    fig.tight_layout()

    plt.show()

show_count_sent(get_source_label(data['source']),positifTest['source'],negatifTest['source'],'Naive Bayes Sentiment')

# %% [markdown]
# visualize the word with particular sentiment (positive, negative) with wordcloud base on device

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import imageio as imageio

# %%
def wordcloud (teks,title) :
    #background_mask = imageio.imread("speech-bubble.png")
    wc = WordCloud(background_color="black",
                   stopwords=STOPWORDS,
                   width=1800,
                   height=1400,)
                   #mask=background_mask)
    if not teks:
        teks = 'none'
    wordcloud = wc.generate(teks)
    return wordcloud

def display_wordcloud(wordcloud, title, n_components):
    print(title.title())
    plt.figure(figsize=(30, 8))
    j = np.ceil(n_components/4)
    for t in range(n_components):
        i=t+1
        plt.subplot(j, 4, i).set_title("sentimen #" + str(t))
        plt.plot()
        plt.imshow(wordcloud[t], cmap=plt.cm.jet, interpolation="bilinear", aspect='auto'); plt.xticks(()); plt.yticks(())
        plt.axis("off")
    fig.suptitle(title)
    plt.show()
    
def get_klas_tweet_nb(source,sentimen):
    source_data = data.loc[data.label==sentimen]
    sent_source_data = source_data.loc[source_data.source==source,'text']
    teks_data = " ".join(str(v) for v in sent_source_data)
    return teks_data

# %%
source = get_source_label(data['source'])

for i in source:
    wordcl = [wordcloud(get_klas_tweet_nb(i,"positif"),i),wordcloud(get_klas_tweet_nb(i,"negatif"),i)]
    display_wordcloud(wordcl, i, 2)
