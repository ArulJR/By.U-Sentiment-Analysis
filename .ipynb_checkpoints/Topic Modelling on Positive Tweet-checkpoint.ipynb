# %%
import pandas as pd

df = pd.read_csv("tweet_pos.csv")

# %%
df.head(50)
# Out:
#                  source                                               text  \
# 0   Twitter for Android  happy 1st anniversary sering sering traktir kuota
# 1   Twitter for Android                                   beli kuota kapan
# 2   Twitter for Android  techi waktu masih 17 tahun loh dia pikir mungk...
# 3   Twitter for Android  indosat sinyal hari enggak jelek bulan depan e...
# 4   Twitter for Android  beli kartu by telkomsel lewat link biar pakai ...
# 5   Twitter for Android  kuota mau habis tiba notifikasi begini terimak...
# 6   Twitter for Android                                   wah 1 tahun kita
# 7   Twitter for Android                                         anak siapa
# 8   Twitter for Android  baik asih kuota gratis monthiversary huhuh ter...
# 9    Twitter for iPhone  beberapa relasi amp kolega jakarta pakai mari ...
# 10   Twitter for iPhone  mau beli kuota di sini by sinyal jelek yowes p...
# 11  Twitter for Android  halo temanteman bantu teman lulus yuk kriteria...
# 12  Twitter for Android                           mau raya anniversary nih
# 13  Twitter for Android  kemarin kan beli kartu terus pilih 1mbps sama ...
# 14   Twitter for iPhone       pakai by tapi paket miskin alias 5gb 15 ribu
# 15  Twitter for Android  guys mau tanya yang pakai kartu itu ke rumah n...
# 16  Twitter for Android  sini adda pakai provider minta ulas dong bagus...
# 17   Twitter for iPhone  halo admin saya pakai kuota 10gb per hari kok ...
# 18   Twitter for iPhone  baru ecek sisa kuota telkomsel yang nyata sisa...
# 19   Twitter for iPhone             mau keluh soal kartu lagi sudah sering
# 20  Twitter for Android  yuhu asa pakai sudah 9 bulan kado seperti kaya...
# 21  Twitter for Android               dadah jaring leluhur jauh lebih baik
# 22  Twitter for Android  kuota habis mau beli kok paket banyak semua ap...
# 23  Twitter for Android  butuh sim card baru terus ingat by akhir beli ...
# 24   Twitter for iPhone                                     seru gila gaul
# 25  Twitter for Android  sumpah jatuh cinta sama uiux nya tolong sama d...
# 26  Twitter for Android                     halo mas tolong cek dm penting
# 27      Twitter Web App  malas isi paket 2 kali akhir pekan panjang di ...
# 28  Twitter for Android  lebih 1paketan murah 2 sosial media musik yout...
# 29  Twitter for Android  pernah pakai enggak itu bagaimana sistem paket...
# 30  Twitter for Android                   kalau paket habis ada asih kabar
# 31   Twitter for iPhone  by yang unlimited cepat sih aku pakai telkomse...
# 32   Twitter for iPhone            coba hitung berapa kali bikin amuk hari
# 33  Twitter for Android                          pulsa benar bisa ubah apa
# 34  Twitter for Android  wow akhir provider internet bebas kamu bikin p...
# 35   Twitter for iPhone  promo kartu perdana 10 ribu 7gb bagi kuota mal...
# 36  Twitter for Android                            terimakasih sayang sama
# 37  Twitter for Android   yey anniversary 1th nih sama btw thankyouu bonus
# 38   Twitter for iPhone   pengin daftar kartu boleh request ponsel nya sih
# 39  Twitter for Android  wow sudah jadi certified anak nih ku kasih tam...
# 40  Twitter for Android             kaget dong bonus kuota byu baik emangg
# 41   Twitter for iPhone                  baik sih asih kuota gratis melulu
# 42  Twitter for Android              haha tau deh aku habis kuota hikszrot
# 43      Twitter Web App  terima kasih hadiah 1st anniversary nya paket ...
# 44  Twitter for Android           cara ubah kuota ajar jadi kuota internet
# 45   Twitter for iPhone  mau beli kartu lagi kalau satu ktp 2 provider ...
# 46  Twitter for Android  alhamdulillah terimakasih sekali dipasih kuota...
# 47   Twitter for iPhone                                           baik byu
# 48   Twitter for iPhone     ikut yang pakap chip provider by kah mau tanya
# 49  Twitter for Android                     ini benerbener doh cinta benar
#
#       label
# 0   positif
# 1   positif
# 2   positif
# 3   positif
# 4   positif
# 5   positif
# 6   positif
# 7   positif
# 8   positif
# 9   positif
# 10  positif
# 11  positif
# 12  positif
# 13  positif
# 14  positif
# 15  positif
# 16  positif
# 17  positif
# 18  positif
# 19  positif
# 20  positif
# 21  positif
# 22  positif
# 23  positif
# 24  positif
# 25  positif
# 26  positif
# 27  positif
# 28  positif
# 29  positif
# 30  positif
# 31  positif
# 32  positif
# 33  positif
# 34  positif
# 35  positif
# 36  positif
# 37  positif
# 38  positif
# 39  positif
# 40  positif
# 41  positif
# 42  positif
# 43  positif
# 44  positif
# 45  positif
# 46  positif
# 47  positif
# 48  positif
# 49  positif

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory, ArrayDictionary, StopWordRemover

stop_factory = StopWordRemoverFactory().get_stop_words()
more_stopword = ['enggak','banget','sih','nih','yang','deh','sangat','ini','kalau','buat','kira','s3','oy','byu','aku','enzyhilman','ku','ah','nya','asih']
 
# Merge stopword
stopword = stop_factory + more_stopword
 
dictionary = ArrayDictionary(stopword)
r_sw = StopWordRemover(dictionary)

df['text'] = df['text'].apply(lambda x : r_sw.remove(x))

# %%
import nltk

df['token'] = df['text'].apply(lambda text : nltk.word_tokenize(text))

# %%
from sklearn.feature_extraction.text import CountVectorizer
from gensim.corpora import Dictionary
from gensim.models.ldamodel import LdaModel
from gensim.models import CoherenceModel
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from datetime import datetime
import nltk
nltk.download('stopwords')
import pandas as pd
import re
import math
import matplotlib.pyplot as plt
from matplotlib import gridspec
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Manaarul
# [nltk_data]     Hidayat\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df.head(10)
# Out:
#                 source                                               text  \
# 0  Twitter for Android  happy 1st anniversary sering sering traktir kuota
# 1  Twitter for Android                                   beli kuota kapan
# 2  Twitter for Android  techi waktu 17 tahun loh pikir mungkin dunia l...
# 3  Twitter for Android   indosat sinyal hari jelek bulan depan jadi ganti
# 4  Twitter for Android  beli kartu telkomsel lewat link biar pakai kod...
# 5  Twitter for Android  kuota mau habis tiba notifikasi begini terimak...
# 6  Twitter for Android                                        wah 1 tahun
# 7  Twitter for Android                                         anak siapa
# 8  Twitter for Android  baik kuota gratis monthiversary huhuh terimakasih
# 9   Twitter for iPhone      beberapa relasi amp kolega jakarta pakai coba
#
#      label                                              token
# 0  positif  [happy, 1st, anniversary, sering, sering, trak...
# 1  positif                               [beli, kuota, kapan]
# 2  positif  [techi, waktu, 17, tahun, loh, pikir, mungkin,...
# 3  positif  [indosat, sinyal, hari, jelek, bulan, depan, j...
# 4  positif  [beli, kartu, telkomsel, lewat, link, biar, pa...
# 5  positif  [kuota, mau, habis, tiba, notifikasi, begini, ...
# 6  positif                                    [wah, 1, tahun]
# 7  positif                                      [anak, siapa]
# 8  positif  [baik, kuota, gratis, monthiversary, huhuh, te...
# 9  positif  [beberapa, relasi, amp, kolega, jakarta, pakai...

# %%
def get_most_freq_words(str, n=None):
    vect = CountVectorizer().fit(str)
    bag_of_words = vect.transform(str)
    sum_words = bag_of_words.sum(axis=0) 
    freq = [(word, sum_words[0, idx]) for word, idx in vect.vocabulary_.items()]
    freq =sorted(freq, key = lambda x: x[1], reverse=True)
    return freq[:n]
  
get_most_freq_words([ word for tweet in df.token for word in tweet],10)
# Out:
# [('ribu', 150),
#  ('50', 141),
#  ('pakai', 140),
#  ('25gb', 134),
#  ('cuma', 118),
#  ('paket', 114),
#  ('promo', 97),
#  ('beli', 95),
#  ('kuota', 90),
#  ('murah', 79)]

# %%
# build a dictionary where for each tweet, each word has its own id.
# We have 6882 tweets and 10893 words in the dictionary.
tweets_dictionary = Dictionary(df.token)

# build the corpus i.e. vectors with the number of occurence of each word per tweet
tweets_corpus = [tweets_dictionary.doc2bow(tweet) for tweet in df.token]

# compute coherence
tweets_coherence = []
for nb_topics in range(1,36):
    lda = LdaModel(tweets_corpus, num_topics = nb_topics, id2word = tweets_dictionary, passes=10)
    cohm = CoherenceModel(model=lda, corpus=tweets_corpus, dictionary=tweets_dictionary, coherence='u_mass')
    coh = cohm.get_coherence()
    tweets_coherence.append(coh)

# visualize coherence
plt.figure(figsize=(10,5))
plt.plot(range(1,36),tweets_coherence)
plt.xlabel("Number of Topics")
plt.ylabel("Coherence Score");

# %%
k = 4
tweets_lda = LdaModel(tweets_corpus, num_topics = k, id2word = tweets_dictionary, passes=100)

def plot_top_words(lda=tweets_lda, nb_topics=k, nb_words=20):
    top_words = [[word for word,_ in lda.show_topic(topic_id, topn=50)] for topic_id in range(lda.num_topics)]
    top_betas = [[beta for _,beta in lda.show_topic(topic_id, topn=50)] for topic_id in range(lda.num_topics)]

    gs  = gridspec.GridSpec(round(math.sqrt(k))+1,round(math.sqrt(k))+1)
    gs.update(wspace=0.5, hspace=0.5)
    plt.figure(figsize=(10,15))
    for i in range(nb_topics):
        ax = plt.subplot(gs[i])
        plt.barh(range(nb_words), top_betas[i][:nb_words], align='center',color='blue', ecolor='black')
        ax.invert_yaxis()
        ax.set_yticks(range(nb_words))
        ax.set_yticklabels(top_words[i][:nb_words])
        plt.title("Topic "+str(i))
        
  
plot_top_words()
