# %%
import pandas as pd
import re
import string
from tqdm.notebook import tqdm
import nltk
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pickle
from gensim.summarization import summarize, keywords
from collections import Counter
from nltk.tokenize import word_tokenize

# %%
data = pd.read_csv("coba_contoh.csv")

data.head()
# Out:
#                   created_at  \
# 0  2020-11-02 08:52:06+00:00
# 1  2020-11-02 08:56:15+00:00
# 2  2020-11-02 08:46:38+00:00
# 3  2020-11-02 06:41:32+00:00
# 4  2020-11-02 05:57:00+00:00
#
#                                               source  \
# 0  <a href="http://twittbot.net/" rel="nofollow">...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/android" ...
#
#                                                 text       label
# 0  Luhan Byu-Ti-Pul Byu-Ti-Pul Byu-Ti-Pul, Luhan ...  irrelevant
# 1  Apa apaan nih, tiba tiba @Telkomsel ilang siny...     negatif
# 2  siang siang dpt kouta gratis dri kak nindy, ma...     positif
# 3            ini byu dr kemaren lelet bener deh hhhh     negatif
# 4  ga salah emang milih provider byU hampir setah...     positif

# %%
data = data[~data.label.str.contains("irrelevant")]

data.reset_index(drop=True, inplace=True)

data.head(20)
# Out:
#                   created_at  \
# 0  2020-11-02 08:56:15+00:00
# 1  2020-11-02 08:46:38+00:00
# 2  2020-11-02 06:41:32+00:00
# 3  2020-11-02 05:57:00+00:00
# 4  2020-11-02 05:14:40+00:00
# 5  2020-11-02 04:31:14+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/android" ...
# 5  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text    label
# 0  Apa apaan nih, tiba tiba @Telkomsel ilang siny...  negatif
# 1  siang siang dpt kouta gratis dri kak nindy, ma...  positif
# 2            ini byu dr kemaren lelet bener deh hhhh  negatif
# 3  ga salah emang milih provider byU hampir setah...  positif
# 4  Min kok kuota spotify sama youtube gak bisa di...  negatif
# 5  Selamat 6 monthiversary, makasih ya kuota grat...  positif

# %%
from bs4 import BeautifulSoup
from pymongo import MongoClient

data['source'] = data['source'].apply(lambda x: BeautifulSoup(x).get_text())

data['source']
# Out:
# 0    Twitter for Android
# 1    Twitter for Android
# 2     Twitter for iPhone
# 3    Twitter for Android
# 4    Twitter for Android
# 5     Twitter for iPhone
# Name: source, dtype: object
